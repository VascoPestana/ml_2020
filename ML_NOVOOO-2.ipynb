# %%
# Import relevant libraries
import sqlite3
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil

# for better resolution plots
# %config InlineBackend.figure_format = 'retina' # optionally, you can change 'svg' to 'retina'

# Setting seaborn style
sns.set()

# %%
# Get the dataset and checking its first rows
df_train = pd.read_excel(r'Train.xlsx')
df_train.head()
# Out:
#    CITIZEN_ID                  Name          Birthday Native Continent  \
# 0       12486       Mr. Adam Glover       July 1,2003           Europe
# 1       12487  Mr. Cameron McDonald   January 25,2006           Europe
# 2       12488    Mr. Keith Davidson       May 10,2009           Europe
# 3       12489    Mr. Alexander Gill     March 25,1985           Europe
# 4       12490        Mr. Neil Piper       May 29,2015           Europe
#
#   Marital Status    Lives with  Base Area               Education Level  \
# 0        Married          Wife  Northbury  High School + PostGraduation
# 1        Married          Wife  Northbury           Professional School
# 2        Married          Wife  Northbury           Professional School
# 3        Married          Wife  Northbury       High School - 2nd Cycle
# 4         Single  Other Family  Northbury                           PhD
#
#    Years of Education           Employment Sector                    Role  \
# 0                  13  Private Sector - Services   Repair & constructions
# 1                  12      Public Sector - Others  Repair & constructions
# 2                  12  Private Sector - Services                    Sales
# 3                  11  Private Sector - Services                 Security
# 4                  21  Self-Employed (Individual)               Professor
#
#    Working Hours per week  Money Received  Ticket Price  Income
# 0                      40               0          2273       1
# 1                      40               0             0       1
# 2                      46               0          2321       1
# 3                      37            5395             0       1
# 4                      45               0             0       1

# %% [markdown]
# ## Data Exploration

# %%
# Checking data types and nulls in the dataset --> see there are no nulls
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22400 entries, 0 to 22399
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CITIZEN_ID              22400 non-null  int64
#  1   Name                    22400 non-null  object
#  2   Birthday                22400 non-null  object
#  3   Native Continent        22400 non-null  object
#  4   Marital Status          22400 non-null  object
#  5   Lives with              22400 non-null  object
#  6   Base Area               22400 non-null  object
#  7   Education Level         22400 non-null  object
#  8   Years of Education      22400 non-null  int64
#  9   Employment Sector       22400 non-null  object
#  10  Role                    22400 non-null  object
#  11  Working Hours per week  22400 non-null  int64
#  12  Money Received          22400 non-null  int64
#  13  Ticket Price            22400 non-null  int64
#  14  Income                  22400 non-null  int64
# dtypes: int64(6), object(9)
# memory usage: 2.6+ MB

# %%
# Birthday is type object, so we're transforming it to type datetime
# For that we must first fix the problem of having February 29 for non-leap years --> turn all February 29 to February 28
from datetime import datetime

df_train['Birthday']=df_train['Birthday'].map(lambda x: x.replace("February 29", "February 28"))

# Check if the replacement worked
df_train['Birthday'][df_train['Birthday'].str.contains("February 29")]
# Out:
# Series([], Name: Birthday, dtype: object)

# %%
# Change the format the date appears and the data type to datetime
df_train['Birthday']=df_train['Birthday'].map(lambda x: datetime.strptime(x, " %B %d,%Y").date())
df_train['Birthday'] = pd.to_datetime(df_train['Birthday'])

# %%
# Get a descriptive overview of the variables (both numeric and categorical)
df_train.describe(include="all")
# Out:
#           CITIZEN_ID              Name             Birthday Native Continent  \
# count   22400.000000             22400                22400            22400
# unique           NaN             16074                11229                5
# top              NaN  Mr. Connor Blake  2025-08-15 00:00:00           Europe
# freq             NaN                 4                    9            19111
# first            NaN               NaN  1958-01-01 00:00:00              NaN
# last             NaN               NaN  2031-10-11 00:00:00              NaN
# mean    23685.500000               NaN                  NaN              NaN
# std      6466.467351               NaN                  NaN              NaN
# min     12486.000000               NaN                  NaN              NaN
# 25%     18085.750000               NaN                  NaN              NaN
# 50%     23685.500000               NaN                  NaN              NaN
# 75%     29285.250000               NaN                  NaN              NaN
# max     34885.000000               NaN                  NaN              NaN
#
#        Marital Status Lives with  Base Area      Education Level  \
# count           22400      22400      22400                22400
# unique              7          6         40                   16
# top           Married       Wife  Northbury  Professional School
# freq            10219       9012      20074                 7232
# first             NaN        NaN        NaN                  NaN
# last              NaN        NaN        NaN                  NaN
# mean              NaN        NaN        NaN                  NaN
# std               NaN        NaN        NaN                  NaN
# min               NaN        NaN        NaN                  NaN
# 25%               NaN        NaN        NaN                  NaN
# 50%               NaN        NaN        NaN                  NaN
# 75%               NaN        NaN        NaN                  NaN
# max               NaN        NaN        NaN                  NaN
#
#         Years of Education           Employment Sector       Role  \
# count         22400.000000                       22400      22400
# unique                 NaN                           9         15
# top                    NaN  Private Sector - Services   Professor
# freq                   NaN                       15599       2849
# first                  NaN                         NaN        NaN
# last                   NaN                         NaN        NaN
# mean             13.173884                         NaN        NaN
# std               2.512451                         NaN        NaN
# min               2.000000                         NaN        NaN
# 25%              12.000000                         NaN        NaN
# 50%              13.000000                         NaN        NaN
# 75%              15.000000                         NaN        NaN
# max              21.000000                         NaN        NaN
#
#         Working Hours per week  Money Received  Ticket Price        Income
# count             22400.000000    22400.000000  22400.000000  22400.000000
# unique                     NaN             NaN           NaN           NaN
# top                        NaN             NaN           NaN           NaN
# freq                       NaN             NaN           NaN           NaN
# first                      NaN             NaN           NaN           NaN
# last                       NaN             NaN           NaN           NaN
# mean                 40.483795     1324.915357    109.145313      0.237098
# std                  12.370921     9227.771813    500.208904      0.425313
# min                   1.000000        0.000000      0.000000      0.000000
# 25%                  40.000000        0.000000      0.000000      0.000000
# 50%                  40.000000        0.000000      0.000000      0.000000
# 75%                  45.000000        0.000000      0.000000      0.000000
# max                  99.000000   122999.000000   5358.000000      1.000000

# %%
# Define Citizen_ID as the index
df_train.set_index("CITIZEN_ID", inplace=True)

# Define Income variable as the target and remove it from the dataframe with the independent variables
target = df_train['Income']
df_train = df_train.drop(['Income'], axis=1)

# Define metric and non-metric datasets
metric= df_train.loc[:, np.array(df_train.dtypes=="int64")]
non_metric= df_train.loc[:,np.array(df_train.dtypes=="object")]

# %%
# Get only the year from Birthday, so as to get a better visualization of the values
metric['Birthday']=df_train.Birthday.map(lambda x: x.year)

# Remove Name from the list of non_metric variables since that gives us no meaning or valuable information and plotting it would be useless
non_metric.drop(columns="Name", inplace=True)
# Out:
# <ipython-input-56-86cd2c956a35>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metric['Birthday']=df_train.Birthday.map(lambda x: x.year)
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# Checking metrics variables' distribution and pairwise relationship
sns.set(style="whitegrid")

# Setting pairgrid
g = sns.PairGrid(metric)

# Populating pairgrid
mdg = g.map_diag(plt.hist, edgecolor="w", color="peru")
mog = g.map_offdiag(plt.scatter, edgecolor="w", color="peru", s=40)
    
# Layout
plt.subplots_adjust(top=0.92)
plt.suptitle("Pairwise relationship of metric variables", fontsize=25)

plt.show()

# %%
# Funciona
sns.set_style("whitegrid")
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(30,40))

ax1=sns.countplot(non_metric["Native Continent"], ax=axes[0,0])
ax2=sns.countplot(non_metric["Lives with"], ax=axes[0,1])
ax3=sns.countplot(non_metric["Marital Status"], ax=axes[1,0])
ax4=sns.countplot(non_metric["Base Area"], ax=axes[1,1])
ax5=sns.countplot(non_metric["Employment Sector"], ax=axes[2,0])
ax6=sns.countplot(non_metric["Education Level"], ax=axes[2,1])
ax7=sns.countplot(non_metric["Role"], ax=axes[3,0])
# ax8=sns.countplot(non_metric["Birthday"], ax=axes[3,1])

ax1.tick_params(labelsize=17)
ax1.set_xlabel(xlabel='Native Continent',fontsize = 19)

ax2.tick_params(labelsize=17)
ax2.set_xlabel(xlabel='Marital Status',fontsize = 19)

ax3.tick_params(labelsize=17)
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=90)
ax3.set_xlabel(xlabel='Lives With',fontsize = 19)

ax4.tick_params(labelsize=17)
ax4.set_xticklabels(ax4.get_xticklabels(), rotation=90)
ax4.set_xlabel(xlabel='Base Area',fontsize = 19)

ax5.tick_params(labelsize=17)
ax5.set_xticklabels(ax5.get_xticklabels(), rotation=90)
ax5.set_xlabel(xlabel='Employment Sector',fontsize = 19)

ax6.tick_params(labelsize=17)
ax6.set_xticklabels(ax6.get_xticklabels(), rotation=90)
ax6.set_xlabel(xlabel='Education Level',fontsize = 19)

ax7.tick_params(labelsize=17)
ax7.set_xticklabels(ax7.get_xticklabels(), rotation=90)
ax7.set_xlabel(xlabel='Role',fontsize = 19)

# ax8.tick_params(labelsize=17)
# ax8.set_xticklabels(ax.get_xticklabels(), rotation=90)
# ax8.set_xlabel(xlabel='Birthday',fontsize = 19)

plt.subplots_adjust(top=0.95,hspace=0.75)
plt.suptitle("Distribution of non-metric variables", fontsize=40)
# Out:
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 0.98, 'Distribution of non-metric variables')

# %%
# Looking at the plots above, we can see the distribution of the values per category, for each categorical variables.
# With this, we see that there are 3 variables containing "?" as a value, which we understand are be null values
# So, here we are replacing those ? for null values, to analyze them more efficiently
df_train=df_train.replace('?', np.nan)

# %%
# Now we can already see how many missing values each variable has
df_train.isna().sum()
# Out:
# Name                         0
# Birthday                     0
# Native Continent             0
# Marital Status               0
# Lives with                   0
# Base Area                  395
# Education Level              0
# Years of Education           0
# Employment Sector         1264
# Role                      1271
# Working Hours per week       0
# Money Received               0
# Ticket Price                 0
# dtype: int64

# %%
#inutil mas func
sns.set(style="white")

# Compute the correlation matrix
corr = metric.corr() #Getting correlation of numerical variables

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool) #Return an array of zeros (Falses) with the same shape and type as a given array
mask[np.triu_indices_from(mask)] = True #The upper-triangle array is now composed by True values

# Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(12, 8))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True) #Make a diverging palette between two HUSL colors. Return a matplotlib colormap object.

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, ax=ax, annot=True)

# Layout
plt.subplots_adjust(top=0.95)
plt.suptitle("Correlation matrix", fontsize=20)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
# Fixing the bug of partially cut-off bottom and top cells
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values

plt.show()

# %%
pd.set_option('display.max_rows', 500)
df_train.groupby(["Base Area","Role"])["Role"].count()
# Out:
# Base Area      Role
# Aberuthven     Administratives                      5
#                Cleaners & Handlers                  3
#                Household Services                   1
#                IT                                   1
#                Machine Operators & Inspectors       4
#                Other services                       2
#                Professor                            1
#                Repair & constructions               4
#                Sales                                2
# Aerilon        Administratives                      2
#                Agriculture and Fishing              1
#                Cleaners & Handlers                  6
#                Household Services                   1
#                IT                                   2
#                Machine Operators & Inspectors       6
#                Management                           3
#                Other services                       1
#                Professor                            6
#                Repair & constructions               9
#                Sales                                3
#                Transports                           3
# Alverton       Administratives                     28
#                Agriculture and Fishing              3
#                Cleaners & Handlers                  4
#                Household Services                   1
#                IT                                   9
#                Machine Operators & Inspectors      10
#                Management                           9
#                Other services                      22
#                Professor                           19
#                Repair & constructions               6
#                Sales                               13
#                Security                             2
#                Transports                           1
# Aroonshire     Administratives                      7
#                Agriculture and Fishing              1
#                Cleaners & Handlers                  3
#                Household Services                   1
#                Machine Operators & Inspectors       6
#                Management                          14
#                Other services                       8
#                Professor                            7
#                Repair & constructions               4
#                Sales                                6
#                Transports                           6
# Auchenshuggle  Administratives                      3
#                Agriculture and Fishing              2
#                Cleaners & Handlers                  7
#                Household Services                   5
#                Machine Operators & Inspectors       4
#                Management                           2
#                Other services                      29
#                Professor                            4
#                Repair & constructions              14
#                Sales                                5
#                Transports                           3
# Bellenau       Machine Operators & Inspectors       2
#                Management                           3
#                Professor                            2
#                Security                             1
# Bellmoral      Administratives                      6
#                Cleaners & Handlers                  2
#                Household Services                   1
#                IT                                   1
#                Machine Operators & Inspectors       6
#                Management                           2
#                Other services                       5
#                Professor                            3
#                Repair & constructions               8
#                Sales                                2
#                Transports                           2
# Butterpond     Administratives                     14
#                Cleaners & Handlers                  4
#                IT                                   1
#                Machine Operators & Inspectors       5
#                Management                          12
#                Other services                       3
#                Professor                           26
#                Repair & constructions               9
#                Sales                                9
#                Security                             4
#                Transports                           3
# Carlisle       Administratives                      4
#                IT                                   2
#                Machine Operators & Inspectors       2
#                Management                           1
#                Other services                       3
#                Professor                            1
#                Repair & constructions               2
#                Sales                                1
#                Transports                           1
# Cherrytown     Administratives                      3
#                Cleaners & Handlers                  4
#                Household Services                   1
#                Machine Operators & Inspectors      12
#                Management                           1
#                Other services                      10
#                Professor                            3
#                Repair & constructions               5
#                Sales                                5
#                Security                             1
#                Transports                           3
# Conriston      Administratives                      1
#                Machine Operators & Inspectors       1
#                Management                           3
#                Other services                       3
#                Professor                            3
#                Security                             1
# Drumchapel     Administratives                      3
#                Agriculture and Fishing              1
#                Cleaners & Handlers                  3
#                Machine Operators & Inspectors       4
#                Management                           2
#                Repair & constructions               7
#                Sales                                1
#                Security                             1
# Eelry          Administratives                      7
#                Agriculture and Fishing              2
#                Cleaners & Handlers                  3
#                Machine Operators & Inspectors       8
#                Management                           6
#                Other services                       9
#                Professor                            8
#                Repair & constructions               7
#                Sales                                3
# Fanfoss        Administratives                     25
#                Agriculture and Fishing             48
#                Cleaners & Handlers                 48
#                Household Services                   9
#                IT                                   1
#                Machine Operators & Inspectors      66
#                Management                           8
#                Other services                      89
#                Professor                           12
#                Repair & constructions              72
#                Sales                               25
#                Security                             3
#                Transports                          16
# Fool's March   Administratives                      4
#                Agriculture and Fishing              1
#                Cleaners & Handlers                  2
#                Household Services                   2
#                IT                                   2
#                Machine Operators & Inspectors       3
#                Management                          12
#                Other services                       5
#                Professor                           12
#                Repair & constructions               5
#                Sales                                7
#                Security                             1
# Ironforge      Machine Operators & Inspectors       1
# Kald           Administratives                      1
#                Agriculture and Fishing              1
#                Household Services                   1
#                IT                                   1
#                Management                           4
#                Other services                       2
#                Professor                            5
#                Sales                                2
#                Security                             1
# King's Watch   Administratives                      2
#                Agriculture and Fishing              3
#                Cleaners & Handlers                  6
#                Household Services                   8
#                IT                                   2
#                Machine Operators & Inspectors       7
#                Other services                       3
#                Professor                            1
#                Repair & constructions               8
#                Sales                                2
#                Security                             1
#                Transports                           1
# Kirkwall       Administratives                      5
#                Agriculture and Fishing              1
#                Cleaners & Handlers                  1
#                Management                           9
#                Other services                       8
#                Professor                            6
#                Repair & constructions               5
#                Sales                                2
#                Security                             1
# Knife's Edge   Administratives                      2
#                IT                                   1
#                Management                           9
#                Other services                       1
#                Professor                           16
#                Repair & constructions               2
#                Sales                                2
# Laenteglos     Administratives                      1
#                IT                                   1
#                Management                           8
#                Other services                       4
#                Professor                            8
#                Repair & constructions               2
#                Sales                                6
#                Transports                           1
# Laewaes        Administratives                      8
#                Agriculture and Fishing              1
#                Cleaners & Handlers                  3
#                IT                                   4
#                Machine Operators & Inspectors       8
#                Management                           3
#                Other services                      10
#                Professor                            5
#                Repair & constructions               9
#                Sales                                7
#                Security                             2
#                Transports                           2
# Lanercost      Administratives                     13
#                Cleaners & Handlers                  3
#                Household Services                   1
#                IT                                   3
#                Machine Operators & Inspectors       1
#                Management                           7
#                Other services                      10
#                Professor                            3
#                Repair & constructions               2
#                Sales                                5
#                Transports                           3
# Lewes          Agriculture and Fishing              1
#                Cleaners & Handlers                  2
#                Machine Operators & Inspectors       2
#                Management                           1
#                Other services                       2
#                Professor                            4
#                Repair & constructions               4
# Marnmouth      Administratives                      1
#                Machine Operators & Inspectors       5
#                Management                           1
#                Other services                       1
#                Repair & constructions               2
# Mensfield      Cleaners & Handlers                  1
#                Management                           3
#                Other services                       2
#                Professor                            1
#                Repair & constructions               1
#                Sales                                1
# Middlesbrough  Agriculture and Fishing              1
#                Machine Operators & Inspectors       1
#                Other services                       1
#                Professor                            2
#                Repair & constructions               4
#                Sales                                1
# MillerVille    Administratives                      2
#                Agriculture and Fishing              1
#                IT                                   1
#                Machine Operators & Inspectors       2
#                Management                           1
#                Professor                            4
#                Repair & constructions               3
#                Sales                                1
#                Security                             1
# Northbury      Administratives                   2384
#                Agriculture and Fishing            626
#                Army                                 5
#                Cleaners & Handlers                794
#                Household Services                  65
#                IT                                 577
#                Machine Operators & Inspectors    1161
#                Management                        2578
#                Other services                    1931
#                Professor                         2538
#                Repair & constructions            2508
#                Sales                             2336
#                Security                           420
#                Transports                         995
# Orilon         Administratives                      1
#                Cleaners & Handlers                  1
#                Machine Operators & Inspectors       1
#                Management                           7
#                Other services                       3
#                Professor                            2
#                Repair & constructions               3
#                Sales                                4
# Pran           Administratives                     13
#                Agriculture and Fishing              4
#                Cleaners & Handlers                  1
#                Machine Operators & Inspectors      12
#                Management                           6
#                Other services                      12
#                Professor                            8
#                Repair & constructions               8
#                Sales                                4
#                Security                             2
#                Transports                           3
# Redwick Bush   Administratives                      1
#                Management                           1
#                Other services                       1
#                Professor                            3
#                Repair & constructions               1
#                Transports                           1
# Sharnwick      Administratives                     10
#                Cleaners & Handlers                  2
#                IT                                   4
#                Machine Operators & Inspectors       2
#                Management                           7
#                Other services                       3
#                Professor                           27
#                Repair & constructions               4
#                Sales                               10
#                Transports                           1
# Sharpton       Administratives                      2
#                IT                                   2
#                Machine Operators & Inspectors       4
#                Management                           5
#                Other services                      13
#                Professor                           16
#                Repair & constructions               3
#                Sales                                4
# Tranmere       Administratives                      4
#                Cleaners & Handlers                  3
#                Household Services                   1
#                Machine Operators & Inspectors       2
#                Other services                      11
#                Professor                            3
#                Repair & constructions               3
#                Security                             1
#                Transports                           1
# Watford        Administratives                      9
#                Agriculture and Fishing              2
#                IT                                   1
#                Machine Operators & Inspectors       4
#                Management                          10
#                Other services                       6
#                Professor                           17
#                Repair & constructions               9
#                Sales                                4
#                Security                             2
#                Transports                           7
# Wigston        Administratives                      4
#                Machine Operators & Inspectors       2
#                Management                           7
#                Other services                      10
#                Professor                            6
#                Repair & constructions               6
#                Sales                               13
#                Transports                           1
# Willesden      Administratives                      1
#                Household Services                   1
#                IT                                   1
#                Machine Operators & Inspectors       4
#                Other services                       2
#                Repair & constructions               3
#                Sales                                2
#                Transports                           1
# Woodpine       Administratives                      1
#                Cleaners & Handlers                  2
#                Machine Operators & Inspectors       1
#                Management                           1
#                Other services                       1
#                Sales                                1
#                Security                             1
# Name: Role, dtype: int64

# %%
pd.crosstab(df_train['Base Area'], df_train['Role'],  margins = True)
# Out:
# Role           Administratives  Agriculture and Fishing  Army  \
# Base Area
# Aberuthven                   5                        0     0
# Aerilon                      2                        1     0
# Alverton                    28                        3     0
# Aroonshire                   7                        1     0
# Auchenshuggle                3                        2     0
# Bellenau                     0                        0     0
# Bellmoral                    6                        0     0
# Butterpond                  14                        0     0
# Carlisle                     4                        0     0
# Cherrytown                   3                        0     0
# Conriston                    1                        0     0
# Drumchapel                   3                        1     0
# Eelry                        7                        2     0
# Fanfoss                     25                       48     0
# Fool's March                 4                        1     0
# Ironforge                    0                        0     0
# Kald                         1                        1     0
# King's Watch                 2                        3     0
# Kirkwall                     5                        1     0
# Knife's Edge                 2                        0     0
# Laenteglos                   1                        0     0
# Laewaes                      8                        1     0
# Lanercost                   13                        0     0
# Lewes                        0                        1     0
# Marnmouth                    1                        0     0
# Mensfield                    0                        0     0
# Middlesbrough                0                        1     0
# MillerVille                  2                        1     0
# Northbury                 2384                      626     5
# Orilon                       1                        0     0
# Pran                        13                        4     0
# Redwick Bush                 1                        0     0
# Sharnwick                   10                        0     0
# Sharpton                     2                        0     0
# Tranmere                     4                        0     0
# Watford                      9                        2     0
# Wigston                      4                        0     0
# Willesden                    1                        0     0
# Woodpine                     1                        0     0
# All                       2577                      700     5
#
# Role           Cleaners & Handlers  Household Services   IT  \
# Base Area
# Aberuthven                       3                   1    1
# Aerilon                          6                   1    2
# Alverton                         4                   1    9
# Aroonshire                       3                   1    0
# Auchenshuggle                    7                   5    0
# Bellenau                         0                   0    0
# Bellmoral                        2                   1    1
# Butterpond                       4                   0    1
# Carlisle                         0                   0    2
# Cherrytown                       4                   1    0
# Conriston                        0                   0    0
# Drumchapel                       3                   0    0
# Eelry                            3                   0    0
# Fanfoss                         48                   9    1
# Fool's March                     2                   2    2
# Ironforge                        0                   0    0
# Kald                             0                   1    1
# King's Watch                     6                   8    2
# Kirkwall                         1                   0    0
# Knife's Edge                     0                   0    1
# Laenteglos                       0                   0    1
# Laewaes                          3                   0    4
# Lanercost                        3                   1    3
# Lewes                            2                   0    0
# Marnmouth                        0                   0    0
# Mensfield                        1                   0    0
# Middlesbrough                    0                   0    0
# MillerVille                      0                   0    1
# Northbury                      794                  65  577
# Orilon                           1                   0    0
# Pran                             1                   0    0
# Redwick Bush                     0                   0    0
# Sharnwick                        2                   0    4
# Sharpton                         0                   0    2
# Tranmere                         3                   1    0
# Watford                          0                   0    1
# Wigston                          0                   0    0
# Willesden                        0                   1    1
# Woodpine                         2                   0    0
# All                            908                  99  617
#
# Role           Machine Operators & Inspectors  Management  Other services  \
# Base Area
# Aberuthven                                  4           0               2
# Aerilon                                     6           3               1
# Alverton                                   10           9              22
# Aroonshire                                  6          14               8
# Auchenshuggle                               4           2              29
# Bellenau                                    2           3               0
# Bellmoral                                   6           2               5
# Butterpond                                  5          12               3
# Carlisle                                    2           1               3
# Cherrytown                                 12           1              10
# Conriston                                   1           3               3
# Drumchapel                                  4           2               0
# Eelry                                       8           6               9
# Fanfoss                                    66           8              89
# Fool's March                                3          12               5
# Ironforge                                   1           0               0
# Kald                                        0           4               2
# King's Watch                                7           0               3
# Kirkwall                                    0           9               8
# Knife's Edge                                0           9               1
# Laenteglos                                  0           8               4
# Laewaes                                     8           3              10
# Lanercost                                   1           7              10
# Lewes                                       2           1               2
# Marnmouth                                   5           1               1
# Mensfield                                   0           3               2
# Middlesbrough                               1           0               1
# MillerVille                                 2           1               0
# Northbury                                1161        2578            1931
# Orilon                                      1           7               3
# Pran                                       12           6              12
# Redwick Bush                                0           1               1
# Sharnwick                                   2           7               3
# Sharpton                                    4           5              13
# Tranmere                                    2           0              11
# Watford                                     4          10               6
# Wigston                                     2           7              10
# Willesden                                   4           0               2
# Woodpine                                    1           1               1
# All                                      1359        2746            2226
#
# Role           Professor  Repair & constructions  Sales  Security  Transports  \
# Base Area
# Aberuthven             1                       4      2         0           0
# Aerilon                6                       9      3         0           3
# Alverton              19                       6     13         2           1
# Aroonshire             7                       4      6         0           6
# Auchenshuggle          4                      14      5         0           3
# Bellenau               2                       0      0         1           0
# Bellmoral              3                       8      2         0           2
# Butterpond            26                       9      9         4           3
# Carlisle               1                       2      1         0           1
# Cherrytown             3                       5      5         1           3
# Conriston              3                       0      0         1           0
# Drumchapel             0                       7      1         1           0
# Eelry                  8                       7      3         0           0
# Fanfoss               12                      72     25         3          16
# Fool's March          12                       5      7         1           0
# Ironforge              0                       0      0         0           0
# Kald                   5                       0      2         1           0
# King's Watch           1                       8      2         1           1
# Kirkwall               6                       5      2         1           0
# Knife's Edge          16                       2      2         0           0
# Laenteglos             8                       2      6         0           1
# Laewaes                5                       9      7         2           2
# Lanercost              3                       2      5         0           3
# Lewes                  4                       4      0         0           0
# Marnmouth              0                       2      0         0           0
# Mensfield              1                       1      1         0           0
# Middlesbrough          2                       4      1         0           0
# MillerVille            4                       3      1         1           0
# Northbury           2538                    2508   2336       420         995
# Orilon                 2                       3      4         0           0
# Pran                   8                       8      4         2           3
# Redwick Bush           3                       1      0         0           1
# Sharnwick             27                       4     10         0           1
# Sharpton              16                       3      4         0           0
# Tranmere               3                       3      0         1           1
# Watford               17                       9      4         2           7
# Wigston                6                       6     13         0           1
# Willesden              0                       3      2         0           1
# Woodpine               0                       0      1         1           0
# All                 2782                    2742   2489       446        1055
#
# Role             All
# Base Area
# Aberuthven        23
# Aerilon           43
# Alverton         127
# Aroonshire        63
# Auchenshuggle     78
# Bellenau           8
# Bellmoral         38
# Butterpond        90
# Carlisle          17
# Cherrytown        48
# Conriston         12
# Drumchapel        22
# Eelry             53
# Fanfoss          422
# Fool's March      56
# Ironforge          1
# Kald              18
# King's Watch      44
# Kirkwall          38
# Knife's Edge      33
# Laenteglos        31
# Laewaes           62
# Lanercost         51
# Lewes             16
# Marnmouth         10
# Mensfield          9
# Middlesbrough     10
# MillerVille       16
# Northbury      18918
# Orilon            22
# Pran              73
# Redwick Bush       8
# Sharnwick         70
# Sharpton          49
# Tranmere          29
# Watford           71
# Wigston           49
# Willesden         15
# Woodpine           8
# All            20751

# %%
pd.crosstab(df_train['Marital Status'], df_train['Lives with'], margins=True)
# Out:
# Lives with                    Alone  Children  Husband  Other Family  \
# Marital Status
# Divorced                       1113       227        0          1657
# Married                           0        73     1042            12
# Married - Spouse Missing         85        33        0           141
# Married - Spouse in the Army      0         1        7             0
# Separated                       302        69        0           289
# Single                          607      3106        0          3281
# Widow                           255        10        0           397
# All                            2362      3519     1049          5777
#
# Lives with                    Other relatives  Wife    All
# Marital Status
# Divorced                                   75     0   3072
# Married                                    85  9007  10219
# Married - Spouse Missing                   25     0    284
# Married - Spouse in the Army                1     5     14
# Separated                                  39     0    699
# Single                                    422     0   7416
# Widow                                      34     0    696
# All                                       681  9012  22400

# %% [markdown]
# ## Coherence Checks

# %%
#MUDAR
#Check if there is someone with more than 70 years that has Employment Sector not null
df_train[(metric.Birthday<1978)]
#& (metric["Money Received"]==0)] that did not receive money to go
# Out:
#                                Name   Birthday Native Continent  \
# CITIZEN_ID
# 12530           Mrs. Carolyn Tucker 1976-02-03           Europe
# 31099                           40               0             0
# 31221                            1               0             0
# 31325                           40           19472             0
# 31361                           35               0             0
# 31386                           40               0             0
# 31408                           40               0             0
# 31486                           75               0             0
# 31553                           20               0             0
# 31683                           20               0             0
# 31761                           20               0             0
# 31793                           30               0             0
# 31812                           32               0             0
# 31815                            6               0             0
# 31821                           24               0             0
# 31858                           17               0             0
# 32083                           15               0             0
# 32095                           25               0             0
# 32262                           60            2865             0
# 32269                           60               0          2234
# 32417                           33               0             0
# 32428                           30               0             0
# 32552                           50               0          2674
# 32565                           20               0             0
# 32625                           20            4269             0
# 32660                           40               0             0
# 32671                           40            3263             0
# 32805                           20             493             0
# 32819                           25               0             0
# 32858                            3               0             0
# 32880                           12               0             0
# 32996                           25            8269             0
# 33010                            0               0             0
# 33039                           30               0             0
# 33058                           30               0             0
# 33121                           40            4026             0
# 33150                            2               0             0
# 33230                           10               0             0
# 33264                            6               0             0
# 33304                           40            1733             0
# 33307                           35               0             0
# 33377                           40               0             0
# 33451                            2               0             0
# 33561                           18               0             0
# 33743                            1               0             0
# 33756                           24               0             0
# 33793                           10               0             0
# 33796                           40               0             0
# 33873                           20               0             0
# 33977                           30           11545             0
# 34017                           12               0             0
# 34187                           14            4696             0
# 34250                            1               0             0
# 34297                           40               0             0
# 34323                           25               0             0
# 34562                           10               0             0
# 34734                           40            7823             0
# 34828                           28               0             0
# 34845                            2               0          2234

# %%
# Check if there is anyone born after the year of this experiment (2048) 
len(df_train[(metric.Birthday>2048)])
# Out:
# 0

# %%
# Check the oldest year of birth and most recent one
print(metric.Birthday.min(),metric.Birthday.max())
# Out:
# 1958 2031

# %%
# Check if there are negative amounts of money
df_train[(df_train["Money Received"]<0)|(df_train["Ticket Price"]<0)]
# Out:
# Empty DataFrame
# Columns: [Name, Birthday, Native Continent, Marital Status, Lives with, Base Area, Education Level, Years of Education, Employment Sector, Role, Working Hours per week, Money Received, Ticket Price]
# Index: []

# %%
# Check if there is anyone who paid for the ticket and at the same time received money to join the experiment
df_train[(df_train["Ticket Price"]!=0) & (df_train["Money Received"]!=0)]
# Out:
# Empty DataFrame
# Columns: [Name, Birthday, Native Continent, Marital Status, Lives with, Base Area, Education Level, Years of Education, Employment Sector, Role, Working Hours per week, Money Received, Ticket Price]
# Index: []

# %%
# Check if there is anyone with a certain level of education and years of education that don't match at all
df_train.groupby(["Years of Education","Education Level"])["Years of Education"].mean()
# Out:
# Years of Education  Education Level
# 2                   Preschool                                2
# 4                   Primary School                           4
# 6                   Middle School - 1st Cycle                6
# 8                   Middle School - 2nd Cycle                8
# 9                   Middle School Complete                   9
# 10                  High School - 1st Cycle                 10
# 11                  High School - 2nd Cycle                 11
# 12                  High School Complete                    12
#                     Professional School                     12
# 13                  High School + PostGraduation            13
#                     Professional School + PostGraduation    13
# 15                  Bachelors                               15
# 16                  Bachelors + PostGraduation              16
# 17                  Masters                                 17
# 18                  Masters + PostGraduation                18
# 21                  PhD                                     21
# Name: Years of Education, dtype: int64

# %%
df_train['Education Level']=df_train['Education Level'].replace('Preschool', 'No Relevant Education')

# %%
df_train["Education Level"].unique()
# Out:
# array(['High School + PostGraduation', 'Professional School',
#        'High School - 2nd Cycle', 'PhD', 'Bachelors',
#        'Bachelors + PostGraduation', 'Masters', 'High School - 1st Cycle',
#        'High School Complete', 'Masters + PostGraduation',
#        'Professional School + PostGraduation',
#        'Middle School - 2nd Cycle', 'Middle School Complete',
#        'Middle School - 1st Cycle', 'Primary School',
#        'No Relevant Education'], dtype=object)

# %%
df_train['Years of Education']=df_train['Years of Education'].replace(2, 0)

# %%
df_train["Years of Education"].unique()
# Out:
# array([13, 12, 11, 21, 15, 16, 17, 10, 18,  8,  9,  6,  4,  0])

# %%
# Check if there is anyone whose marital status seems incoherent with the person he/she lives with someone
df_train.groupby(["Marital Status","Lives with"] )["Lives with"].count()
# Out:
# Marital Status                Lives with
# Divorced                      Alone              1113
#                               Children            227
#                               Other Family       1657
#                               Other relatives      75
# Married                       Children             73
#                               Husband            1042
#                               Other Family         12
#                               Other relatives      85
#                               Wife               9007
# Married - Spouse Missing      Alone                85
#                               Children             33
#                               Other Family        141
#                               Other relatives      25
# Married - Spouse in the Army  Children              1
#                               Husband               7
#                               Other relatives       1
#                               Wife                  5
# Separated                     Alone               302
#                               Children             69
#                               Other Family        289
#                               Other relatives      39
# Single                        Alone               607
#                               Children           3106
#                               Other Family       3281
#                               Other relatives     422
# Widow                         Alone               255
#                               Children             10
#                               Other Family        397
#                               Other relatives      34
# Name: Lives with, dtype: int64

# %%
#AQUIII

ola=df_train.copy()
ola["age"]=2048-ola.Birthday.map(lambda x: x.year)
ola[ola.Birthday.map(lambda x: 2048-x.year)<(ola["Years of Education"]+5)]
# Out:
#                              Name   Birthday Native Continent Marital Status  \
# CITIZEN_ID
# 14941       Miss Yvonne Henderson 2029-03-25           Africa         Single
# 16528             Miss Ava Glover 2028-07-15           Africa         Single
# 24242         Miss Pippa Anderson 2024-02-01           Europe         Single
# 24843           Mr. Gavin Thomson 2028-09-13           Europe         Single
# 27833            Miss Sue Randall 2030-04-08           Europe         Single
# 28849         Mr. Jonathan Oliver 2031-02-05           Europe         Single
# 33939             Mr. Isaac Alsop 2027-04-20           Europe         Single
#
#                  Lives with     Base Area               Education Level  \
# CITIZEN_ID
# 14941              Children     Lanercost    Bachelors + PostGraduation
# 16528       Other relatives     Northbury    Bachelors + PostGraduation
# 24242          Other Family  Fool's March                           PhD
# 24843              Children     Northbury                       Masters
# 27833              Children     Northbury                       Masters
# 28849              Children     Northbury  High School + PostGraduation
# 33939              Children     Northbury                       Masters
#
#             Years of Education           Employment Sector             Role  \
# CITIZEN_ID
# 14941                       16                         NaN              NaN
# 16528                       16  Private Sector - Services             Sales
# 24242                       21     Private Sector - Others        Professor
# 24843                       17  Private Sector - Services        Management
# 27833                       17      Public Sector - Others        Professor
# 28849                       13  Private Sector - Services   Administratives
# 33939                       17     Private Sector - Others       Transports
#
#             Working Hours per week  Money Received  Ticket Price  age
# CITIZEN_ID
# 14941                           40               0             0   19
# 16528                           30               0             0   20
# 24242                           99               0             0   24
# 24843                           25               0             0   20
# 27833                           60               0             0   18
# 28849                           20               0             0   17
# 33939                           15               0             0   21

# %%
# Check if there is anyone with more years of education than his/her age
df_train[df_train.Birthday.map(lambda x: 2048-x.year)<(df_train["Years of Education"]+5)]
# Out:
#                              Name   Birthday Native Continent Marital Status  \
# CITIZEN_ID
# 14941       Miss Yvonne Henderson 2029-03-25           Africa         Single
# 16528             Miss Ava Glover 2028-07-15           Africa         Single
# 24242         Miss Pippa Anderson 2024-02-01           Europe         Single
# 24843           Mr. Gavin Thomson 2028-09-13           Europe         Single
# 27833            Miss Sue Randall 2030-04-08           Europe         Single
# 28849         Mr. Jonathan Oliver 2031-02-05           Europe         Single
# 33939             Mr. Isaac Alsop 2027-04-20           Europe         Single
#
#                  Lives with     Base Area               Education Level  \
# CITIZEN_ID
# 14941              Children     Lanercost    Bachelors + PostGraduation
# 16528       Other relatives     Northbury    Bachelors + PostGraduation
# 24242          Other Family  Fool's March                           PhD
# 24843              Children     Northbury                       Masters
# 27833              Children     Northbury                       Masters
# 28849              Children     Northbury  High School + PostGraduation
# 33939              Children     Northbury                       Masters
#
#             Years of Education           Employment Sector             Role  \
# CITIZEN_ID
# 14941                       16                         NaN              NaN
# 16528                       16  Private Sector - Services             Sales
# 24242                       21     Private Sector - Others        Professor
# 24843                       17  Private Sector - Services        Management
# 27833                       17      Public Sector - Others        Professor
# 28849                       13  Private Sector - Services   Administratives
# 33939                       17     Private Sector - Others       Transports
#
#             Working Hours per week  Money Received  Ticket Price
# CITIZEN_ID
# 14941                           40               0             0
# 16528                           30               0             0
# 24242                           99               0             0
# 24843                           25               0             0
# 27833                           60               0             0
# 28849                           20               0             0
# 33939                           15               0             0

# %%
#unemployed citizens have Role and Working Hours different than 0
df_train[["Employment Sector", "Role", "Working Hours per week"]][df_train["Employment Sector"]=="Unemployed"]
# Out:
#            Employment Sector                     Role  Working Hours per week
# CITIZEN_ID
# 12567             Unemployed      Cleaners & Handlers                      40
# 15572             Unemployed  Agriculture and Fishing                      10
# 16852             Unemployed               Transports                      20
# 17274             Unemployed          Administratives                      12
# 21062             Unemployed  Agriculture and Fishing                      50
# 22741             Unemployed  Agriculture and Fishing                      20
# 27493             Unemployed   Repair & constructions                      40
# 29340             Unemployed  Agriculture and Fishing                      65
# 33010             Unemployed           Other services                      55
# 33412             Unemployed  Agriculture and Fishing                      50
# 33618             Unemployed          Administratives                      30
# 33720             Unemployed          Administratives                      16

# %%
#Never worked citizens have Role and Working Hours different than 0
df_train[["Employment Sector", "Role", "Working Hours per week"]][df_train["Employment Sector"]=="Never Worked"]
# Out:
#            Employment Sector Role  Working Hours per week
# CITIZEN_ID
# 13792           Never Worked  NaN                      40
# 22674           Never Worked  NaN                      30
# 23583           Never Worked  NaN                      10
# 24701           Never Worked  NaN                      40
# 27002           Never Worked  NaN                       4
# 32390           Never Worked  NaN                      40
# 33185           Never Worked  NaN                      35

# %%
df_train["Working Hours per week"][(df_train["Employment Sector"]=="Unemployed") | (df_train["Employment Sector"]=="Never Worked")]=0
# Out:
# <ipython-input-103-12ba63825440>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train["Working Hours per week"][(df_train["Employment Sector"]=="Unemployed") | (df_train["Employment Sector"]=="Never Worked")]=0

# %%
df_train["Role"][(df_train["Employment Sector"]=="Never Worked")]="No Role"
# Out:
# <ipython-input-104-96312930b535>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train["Role"][(df_train["Employment Sector"]=="Never Worked")]="No Role"

# %%
df_train[["Employment Sector", "Role", "Working Hours per week"]][(df_train["Employment Sector"]=="Unemployed") | (df_train["Employment Sector"]=="Never Worked")]
# Out:
#            Employment Sector                     Role  Working Hours per week
# CITIZEN_ID
# 12567             Unemployed      Cleaners & Handlers                       0
# 13792           Never Worked                  No Role                       0
# 15572             Unemployed  Agriculture and Fishing                       0
# 16852             Unemployed               Transports                       0
# 17274             Unemployed          Administratives                       0
# 21062             Unemployed  Agriculture and Fishing                       0
# 22674           Never Worked                  No Role                       0
# 22741             Unemployed  Agriculture and Fishing                       0
# 23583           Never Worked                  No Role                       0
# 24701           Never Worked                  No Role                       0
# 27002           Never Worked                  No Role                       0
# 27493             Unemployed   Repair & constructions                       0
# 29340             Unemployed  Agriculture and Fishing                       0
# 32390           Never Worked                  No Role                       0
# 33010             Unemployed           Other services                       0
# 33185           Never Worked                  No Role                       0
# 33412             Unemployed  Agriculture and Fishing                       0
# 33618             Unemployed          Administratives                       0
# 33720             Unemployed          Administratives                       0

# %% [markdown]
# ## Outliers

# %%
sns.set(style="whitegrid")

data = pd.melt(metric)
plot_features = metric.columns

#Prepare figure layout
fig, axes = plt.subplots(1, len(plot_features), figsize=(15,8), constrained_layout=True)
    
# Draw the boxplots
for i in zip(axes, plot_features):
    sns.boxplot(x="variable", y="value", data=data.loc[data["variable"]==i[1]], ax=i[0], color='peru')
    i[0].set_xlabel("")
    i[0].set_ylabel("")

# Finalize the plot
plt.suptitle("Metric variables' box plots", fontsize=25)
sns.despine(bottom=True)

plt.show()

# %%
#test
df_train[df_train["Money Received"]==122999]
# Out:
#                                Name   Birthday Native Continent  \
# CITIZEN_ID
# 12667          Mr. Alexander Duncan 1997-03-17          Oceania
# 12839                 Mr. Sam Black 1985-05-26           Europe
# 13363             Mr. Jason Dickens 2009-01-20           Europe
# 13419                Mr. Harry Parr 1999-09-29           Europe
# 13445              Mr. Jacob Wilson 2008-06-28           Europe
# 13557              Mr. Liam Abraham 1995-05-17           Europe
# 13759            Mrs. Lauren Morgan 2012-07-31           Africa
# 13809                 Mr. Jack Kerr 2008-05-23             Asia
# 14070           Mr. Joseph Buckland 1992-07-20           Europe
# 14113          Mr. Michael Johnston 2011-06-23           Europe
# 14545         Mrs. Bernadette Allan 1999-04-03           Europe
# 15047               Mr. Peter Short 2017-01-10             Asia
# 15137               Mr. Jason Short 2020-07-25           Africa
# 15158             Mr. Steven Mackay 2005-05-13           Europe
# 15233             Mrs. Ava Metcalfe 1992-02-22           Europe
# 15487                 Mr. Sam Grant 1977-02-28           Europe
# 15614         Mr. Christopher Walsh 2012-08-23           Europe
# 15689              Mr. Lucas Glover 1993-02-25           Europe
# 16717                 Mr. Sam Jones 1990-06-15           Europe
# 16772              Mr. Connor Baker 2000-03-08           Europe
# 33368                        Married          Wife     Northbury
# 33431                        Married          Wife     Northbury
# 33524                        Married       Husband           NaN
# 33710                        Married       Husband           NaN
# 34044                       Divorced  Other Family     Northbury
# 34199                        Married       Husband     Northbury
# 34349                        Married          Wife     Northbury
# 34364                        Married          Wife     Northbury
# 34695                        Married          Wife     Northbury
#
#                                  Education Level  Years of Education  \
# CITIZEN_ID
# 12667                   Masters + PostGraduation                  18
# 12839                        Professional School                  12
# 13363                                    Masters                  17
# 13419                                    Masters                  17
# 13445                   Masters + PostGraduation                  18
# 13557                        Professional School                  12
# 13759               High School + PostGraduation                  13
# 13809                   Masters + PostGraduation                  18
# 14070                   Masters + PostGraduation                  18
# 14113                   Masters + PostGraduation                  18
# 14545                 Bachelors + PostGraduation                  16
# 15047                 Bachelors + PostGraduation                  16
# 15137                        Professional School                  12
# 15158                   Masters + PostGraduation                  18
# 15233                        Professional School                  12
# 15487                                    Masters                  17
# 15614                   Masters + PostGraduation                  18
# 15689                    High School - 1st Cycle                  10
# 16717               High School + PostGraduation                  13
# 16772                 Bachelors + PostGraduation                  16
# 16917                   Masters + PostGraduation                  18
# 16971                 Bachelors + PostGraduation                  16
# 16980               High School + PostGraduation                  13
# 17299                   Masters + PostGraduation                  18
# 17669                   Masters + PostGraduation                  18
# 18248                                    Masters                  17
# 18761                   Masters + PostGraduation                  18
# 19060                   Masters + PostGraduation                  18
# 19124                        Professional School                  12
# 19131                                        PhD                  21
# 19247                   Masters + PostGraduation                  18
# 19322                        Professional School                  12
# 19386                   Masters + PostGraduation                  18
# 19478                                        PhD                  21
# 19498                                    Masters                  17
# 19509                   Masters + PostGraduation                  18
# 19663                 Bachelors + PostGraduation                  16
# 20146                 Bachelors + PostGraduation                  16
# 20169                        Professional School                  12
# 20173                    High School - 1st Cycle                  10
# 20399                                        PhD                  21
# 20594                 Bachelors + PostGraduation                  16
# 21274                 Bachelors + PostGraduation                  16
# 21310               High School + PostGraduation                  13
# 21858                   Masters + PostGraduation                  18
# 22203                   Masters + PostGraduation                  18
# 22407                        Professional School                  12
# 22461                        Professional School                  12
# 22520                                    Masters                  17
# 23183                 Bachelors + PostGraduation                  16
# 23199                   Masters + PostGraduation                  18
# 23236                                        PhD                  21
# 23717                                        PhD                  21
# 24230                                        PhD                  21
# 24549                   Masters + PostGraduation                  18
# 24585               High School + PostGraduation                  13
# 24603                                    Masters                  17
# 24684                   Masters + PostGraduation                  18
# 25405                        Professional School                  12
# 25549                 Bachelors + PostGraduation                  16
# 26061                 Bachelors + PostGraduation                  16
# 26203                                    Masters                  17
# 26219                 Bachelors + PostGraduation                  16
# 26237                        Professional School                  12
# 26314                 Bachelors + PostGraduation                  16
# 26872                 Bachelors + PostGraduation                  16
# 26960               High School + PostGraduation                  13
# 27106                 Bachelors + PostGraduation                  16
# 27135                   Masters + PostGraduation                  18
# 27262                 Bachelors + PostGraduation                  16
# 27288                                    Masters                  17
# 27437                   Masters + PostGraduation                  18
# 27826                   Masters + PostGraduation                  18
# 27999               High School + PostGraduation                  13
# 28080                 Bachelors + PostGraduation                  16
# 28346                 Bachelors + PostGraduation                  16
# 28396                   Masters + PostGraduation                  18
# 28757                        Professional School                  12
# 28805                                    Masters                  17
# 28858                        Professional School                  12
# 29133                 Bachelors + PostGraduation                  16
# 29337                   Masters + PostGraduation                  18
# 29375                   Masters + PostGraduation                  18
# 30037                 Bachelors + PostGraduation                  16
# 30099               High School + PostGraduation                  13
# 30130                 Bachelors + PostGraduation                  16
# 30563                 Bachelors + PostGraduation                  16
# 30838                 Bachelors + PostGraduation                  16
# 31148                                    Masters                  17
# 31347                   Masters + PostGraduation                  18
# 31483                        Professional School                  12
# 31529                 Bachelors + PostGraduation                  16
# 31664                                        PhD                  21
# 31830                 Bachelors + PostGraduation                  16
# 31884                        Professional School                  12
# 32145                                        PhD                  21
# 32311                   Masters + PostGraduation                  18
# 32456                        Professional School                  12
# 32467                   Masters + PostGraduation                  18
# 32501                   Masters + PostGraduation                  18
# 32758                        Professional School                  12
# 32785                        Professional School                  12
# 32807                   Masters + PostGraduation                  18
# 32955       Professional School + PostGraduation                  13
# 33206                 Bachelors + PostGraduation                  16
# 33368                   Masters + PostGraduation                  18
# 33431                                    Masters                  17
# 33524                                  Bachelors                  15
# 33710                 Bachelors + PostGraduation                  16
# 34044                 Bachelors + PostGraduation                  16
# 34199                                    Masters                  17
# 34349                   Masters + PostGraduation                  18
# 34364                                    Masters                  17
# 34695                 Bachelors + PostGraduation                  16
#
#                      Employment Sector                            Role  \
# CITIZEN_ID
# 12667       Self-Employed (Individual)                       Professor
# 12839       Private Sector - Services           Repair & constructions
# 13363       Private Sector - Services                        Professor
# 13419          Private Sector - Others                           Sales
# 13445       Self-Employed (Individual)                       Professor
# 13557          Self-Employed (Company)                           Sales
# 13759       Private Sector - Services                  Administratives
# 13809       Private Sector - Services                        Professor
# 14070          Self-Employed (Company)                       Professor
# 14113       Self-Employed (Individual)                       Professor
# 14545       Private Sector - Services                        Professor
# 15047       Private Sector - Services                   Other services
# 15137          Self-Employed (Company)                           Sales
# 15158       Private Sector - Services                        Professor
# 15233       Self-Employed (Individual)                 Administratives
# 15487          Self-Employed (Company)                      Management
# 15614       Private Sector - Services                        Professor
# 15689       Private Sector - Services           Repair & constructions
# 16717                              NaN                             NaN
# 16772       Self-Employed (Individual)                      Management
# 16917       Private Sector - Services                        Professor
# 16971       Private Sector - Services                       Management
# 16980       Private Sector - Services                       Management
# 17299       Private Sector - Services                        Professor
# 17669       Private Sector - Services                        Professor
# 18248       Self-Employed (Individual)                      Management
# 18761       Self-Employed (Individual)                       Professor
# 19060       Self-Employed (Individual)                       Professor
# 19124       Private Sector - Services                            Sales
# 19131       Private Sector - Services                        Professor
# 19247       Private Sector - Services                        Professor
# 19322          Self-Employed (Company)                      Management
# 19386          Self-Employed (Company)                       Professor
# 19478       Private Sector - Services                       Management
# 19498       Private Sector - Services                       Management
# 19509       Self-Employed (Individual)                       Professor
# 19663       Private Sector - Services                            Sales
# 20146       Private Sector - Services                        Professor
# 20169       Self-Employed (Individual)          Repair & constructions
# 20173           Public Sector - Others             Cleaners & Handlers
# 20399       Private Sector - Services                        Professor
# 20594       Private Sector - Services                       Management
# 21274       Private Sector - Services                       Management
# 21310       Private Sector - Services                         Security
# 21858       Private Sector - Services                        Professor
# 22203          Self-Employed (Company)                       Professor
# 22407          Self-Employed (Company)          Repair & constructions
# 22461       Self-Employed (Individual)                      Management
# 22520       Private Sector - Services                       Management
# 23183          Self-Employed (Company)                           Sales
# 23199       Private Sector - Services                        Professor
# 23236       Private Sector - Services                        Professor
# 23717          Self-Employed (Company)                       Professor
# 24230          Self-Employed (Company)                      Management
# 24549       Private Sector - Services                        Professor
# 24585       Private Sector - Services                       Management
# 24603       Private Sector - Services                       Management
# 24684       Private Sector - Services                       Management
# 25405       Self-Employed (Individual)                           Sales
# 25549       Self-Employed (Individual)                      Management
# 26061       Private Sector - Services                            Sales
# 26203       Private Sector - Services                       Management
# 26219       Private Sector - Services                        Professor
# 26237       Private Sector - Services                   Other services
# 26314       Private Sector - Services                       Management
# 26872          Self-Employed (Company)                      Management
# 26960       Private Sector - Services                  Administratives
# 27106          Self-Employed (Company)                      Management
# 27135       Self-Employed (Individual)                      Management
# 27262       Private Sector - Services                        Professor
# 27288       Private Sector - Services                       Management
# 27437          Self-Employed (Company)                       Professor
# 27826          Self-Employed (Company)                       Professor
# 27999          Self-Employed (Company)                           Sales
# 28080          Self-Employed (Company)                           Sales
# 28346       Private Sector - Services                        Professor
# 28396       Self-Employed (Individual)                       Professor
# 28757       Private Sector - Services                       Management
# 28805       Private Sector - Services                        Professor
# 28858       Private Sector - Services                       Management
# 29133          Self-Employed (Company)                           Sales
# 29337          Self-Employed (Company)                      Management
# 29375          Self-Employed (Company)                       Professor
# 30037       Self-Employed (Individual)                 Administratives
# 30099       Self-Employed (Individual)                           Sales
# 30130                              NaN                             NaN
# 30563       Private Sector - Services                            Sales
# 30838       Private Sector - Services                            Sales
# 31148          Self-Employed (Company)                       Professor
# 31347       Public Sector - Government                       Professor
# 31483       Self-Employed (Individual)                       Professor
# 31529          Self-Employed (Company)                           Sales
# 31664          Self-Employed (Company)                       Professor
# 31830       Private Sector - Services                            Sales
# 31884       Private Sector - Services                       Transports
# 32145       Private Sector - Services                        Professor
# 32311       Private Sector - Services                       Management
# 32456       Private Sector - Services           Repair & constructions
# 32467       Private Sector - Services                        Professor
# 32501       Self-Employed (Individual)                       Professor
# 32758       Private Sector - Services   Machine Operators & Inspectors
# 32785       Private Sector - Services                       Management
# 32807          Self-Employed (Company)                       Professor
# 32955       Private Sector - Services                        Professor
# 33206       Private Sector - Services                       Management
# 33368          Self-Employed (Company)                       Professor
# 33431       Private Sector - Services                       Management
# 33524           Public Sector - Others                       Professor
# 33710          Self-Employed (Company)                      Management
# 34044           Public Sector - Others                 Administratives
# 34199       Private Sector - Services                        Professor
# 34349       Private Sector - Services                        Professor
# 34364          Self-Employed (Company)                           Sales
# 34695          Self-Employed (Company)                      Management
#
#             Working Hours per week  Money Received  Ticket Price
# CITIZEN_ID
# 12667                           70          122999             0
# 12839                           40          122999             0
# 13363                           40          122999             0
000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: Working Hours per week, dtype: float64

# %% [markdown]
# #RECOMENTAR
#
# #using the IQR method to filter outliers: the scatter plot was impossible to analyze with the outliers, and there are some
# #very extreme values on 'precoContratual' and, especially, on 'prazoExecucao'
#
# #calculate the first and third quantiles:
# q25 = df_train['Working Hours per week'].quantile(.25)
# q75 = df_train['Working Hours per week'].quantile(.75)
# #calculate the inter-quartile range:
# iqr = (q75 - q25)
#
# #calculate the lower and upper fence:
# multiplicator = 6 #5 or 6 looks better; with 1.5 (the "official") or 2 you delete too much of the data
# upper_lim = q75 + multiplicator * iqr
# lower_lim = q25 - multiplicator * iqr
#
# #filtering the outliers based on the IQR limits
# df_train_new = df_train[(df_train['Working Hours per week'] > lower_lim) & (df_train['Working Hours per week'] < upper_lim)]
# print('Percentage of data kept after removing outliers:', np.round(df_train_new.shape[0] / df_train.shape[0], 4))

# %% [markdown]
# We decided not to eliminate outliers on "Money Received", since when observing the value that was more distant from the rest, we concluded that there were several people with that high value (122999), all having a relatively important role and high hours of work.
#
# Also, we do not consider relevant the amount itself of money received or payed, but instead, if the person received or payed to go.

# %% [markdown]
# sns.set(style="whitegrid")
# sns.boxplot(x="Working Hours per week", data=df_train_new, color='peru')
# plt.suptitle("Working Hours Without Outliers", fontsize=20)
# plt.show()

# %%
#number of citizens that have less than 7.5 years of education to conclude if they might be outliers
len(df_train[df_train["Years of Education"]<7.5])
# Out:
# 392

# %%
#NAO USAMOS

from numpy.random import seed
from numpy.random import randn
from scipy.stats import shapiro

# normality test
stat, p = shapiro(df_train["Working Hours per week"])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.885, p=0.000
# Sample does not look Gaussian (reject H0)
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:1681: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# ## Missing Values

# %% [markdown]
# #### 1st method - impute with the mode

# %%
df_train1=df_train.copy()

# %%
modes = non_metric.mode().loc[0]
df_train1.fillna(modes, inplace=True)
df_train1.isna().sum()
# Out:
# Name                      0
# Birthday                  0
# Native Continent          0
# Marital Status            0
# Lives with                0
# Base Area                 0
# Education Level           0
# Years of Education        0
# Employment Sector         0
# Role                      0
# Working Hours per week    0
# Money Received            0
# Ticket Price              0
# dtype: int64

# %% [markdown]
# #### 2nd method - imupte with the mode of categories in common

# %%
# understand if certain non-numeric variables are dependent or not from the ones with missing values

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# Create a function that performs the Chi2 test for independence, to check for association between each variable with no missing
# values and each of the ones with missings

def check_association(col1,col2):
    # contingency table
    tab=pd.crosstab(df_train[col1], df_train[col2], margins=False).values
    stat, p, dof, expected = chi2_contingency(tab)

    # interpret test-statistic
    prob = 0.95
    critical = chi2.ppf(prob, dof)
    print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
    
    if abs(stat) >= critical:
        print(col1,'and',col2,'are dependent (reject H0).')
    else:
        print(col1,'and',col2,'are independent (fail to reject H0).')
        
    # interpret p-value
    alpha = 1.0 - prob
    print('significance=%.3f, p=%.3f' % (alpha, p))
    
    if p <= alpha:
        print(col1,'and',col2,'are dependent (reject H0).\n')
    else:
        print(col1,'and',col2,'are independent (fail to reject H0).\n')

# %%
# FIRST: Marital Status

check_association('Marital Status','Base Area')
check_association('Marital Status','Employment Sector')
check_association('Marital Status','Role')
# Out:
# probability=0.950, critical=264.224, stat=707.714
# Marital Status and Base Area are dependent (reject H0).
# significance=0.050, p=0.000
# Marital Status and Base Area are dependent (reject H0).
#
# probability=0.950, critical=58.124, stat=798.754
# Marital Status and Employment Sector are dependent (reject H0).
# significance=0.050, p=0.000
# Marital Status and Employment Sector are dependent (reject H0).
#
# probability=0.950, critical=106.395, stat=2136.649
# Marital Status and Role are dependent (reject H0).
# significance=0.050, p=0.000
# Marital Status and Role are dependent (reject H0).

# %%
# SECOND: Education Level

check_association('Education Level','Base Area')
check_association('Education Level','Employment Sector')
check_association('Education Level','Role')
# Out:
# probability=0.950, critical=626.650, stat=6057.678
# Education Level and Base Area are dependent (reject H0).
# significance=0.050, p=0.000
# Education Level and Base Area are dependent (reject H0).
#
# probability=0.950, critical=129.918, stat=1544.322
# Education Level and Employment Sector are dependent (reject H0).
# significance=0.050, p=0.000
# Education Level and Employment Sector are dependent (reject H0).
#
# probability=0.950, critical=244.808, stat=10712.853
# Education Level and Role are dependent (reject H0).
# significance=0.050, p=0.000
# Education Level and Role are dependent (reject H0).

# %%
# Seeing both of these variables are associated with the three variables with missing values, using the similarities between people
# in these categories, might be useful to discover their characteristics in the missing variables

# %%
# Copy the dataframe into another to apply the changes there before
df_train2=df_train.copy()

# Create a function to impute the missing values by the mode of the records belonging to the same classes of Marital Status and Education Level
def impute_mode_by_cat(col):
    exp=df_train2[df_train2[col].isnull()].reset_index()
    gr=df_train2.groupby(["Education Level","Marital Status"])[col].agg(pd.Series.mode)
    
    # if there are null values in the group by, replace them by the overall mode of the orginal variable
    for i in range(len(gr)):
        if len(gr[i])==0:
            gr[i]=df_train2[col].mode()[0]


    # define the values of base area in the new auxiliary dataset as the mode of the base are values for the observations with the
    # same level of education and marital status, because at least to some extent, they are more similar than the others       
    for i in range(len(exp)):
        for x in range(len(gr)):
            if (exp['Education Level'][i]==gr.index[x][0]) and (exp['Marital Status'][i]==gr.index[x][1]):
                exp[col][i]=gr[x]
                
    # if it's bimodal (has more than one mode, keep only the first one provided)
    for i in range(len(exp)):
        if type(exp[col][i])!=str:
            exp[col][i]=df_train2[col].mode()[0]

    # finally, replace the null values in Base Area in the original dataset by the values acquired before
    for i in range(len(exp)):
        df_train2.loc[exp['CITIZEN_ID'][i],col]=exp[col][i]
        
    return df_train2

# %%
df_train2[df_train2['Base Area'].isnull()]
# Out:
#                                 Name   Birthday Native Continent  \
# CITIZEN_ID
# 12516                 Mr. Jason Gray 2024-09-26           Africa
# 12583               Mr. Joseph Avery 2008-09-06           Europe
# 12700               Mr. Colin Graham 2017-02-14           Europe
# 12771                 Mrs. Emma Gray 2005-02-22           Europe
# 12845         Mr. Alexander Rampling 2022-02-28           Africa
# 12875                 Mr. Owen Scott 2027-07-20           Europe
# 12891           Mr. Anthony McDonald 2020-10-06           Europe
# 12895            Mrs. Bella Hemmings 1991-05-07           Europe
# 12956             Mr. William Wilson 2004-05-20           Europe
# 13158                Miss Wendy Nash 2020-06-16           Europe
# 13213                 Mrs. Karen Lee 1976-05-09           Europe
# 13267           Mr. Steven Sanderson 2010-01-28           Europe
# CITIZEN_ID
# 12516                         Single     Other Family       NaN
# 12583                        Married             Wife       NaN
# 12700                         Single  Other relatives       NaN
# 12771       Married - Spouse Missing     Other Family       NaN
# 12845                         Single     Other Family       NaN
# 12875                         Single         Children       NaN
# 12891                         Single     Other Family       NaN
# 12895                          Widow            Alone       NaN
# 12956                        Married             Wife       NaN
# 13158                         Single     Other Family       NaN
# 13213                          Widow     Other Family       NaN
# 13267                       Divorced            Alone       NaN
# 13369                        Married             Wife       NaN
# 13524                         Single         Children       NaN
# 13526                        Married             Wife       NaN
# 13546                         Single     Other Family       NaN
# 13553                       Divorced            Alone       NaN
# 13574                        Married          Husband       NaN
# 13615                        Married             Wife       NaN
# 13661                        Married             Wife       NaN
# 13697                         Single     Other Family       NaN
# 13716                        Married             Wife       NaN
# 13809                        Married             Wife       NaN
# 13850                        Married             Wife       NaN
# 13852                         Single            Alone       NaN
# 13932                      Separated            Alone       NaN
# 13972                         Single         Children       NaN
# 13978                          Widow  Other relatives       NaN
# 14008                         Single         Children       NaN
# 14086                        Married             Wife       NaN
# 14091                        Married             Wife       NaN
# 14307                        Married             Wife       NaN
# 14309                      Separated     Other Family       NaN
# 14450       Married - Spouse Missing     Other Family       NaN
# 14517                       Divorced     Other Family       NaN
# 14562                         Single  Other relatives       NaN
# 14812                        Married             Wife       NaN
# 14894                        Married             Wife       NaN
# 14905                        Married             Wife       NaN
# 14951                        Married          Husband       NaN
# 15009                         Single     Other Family       NaN
# 15054                         Single         Children       NaN
# 15060                         Single         Children       NaN
# 15090                        Married             Wife       NaN
# 15100                        Married             Wife       NaN
# 15135                        Married             Wife       NaN
# 15161                         Single     Other Family       NaN
# 15300                        Married             Wife       NaN
# 15310                        Married             Wife       NaN
# 15316                         Single     Other Family       NaN
# 15317                        Married             Wife       NaN
# 15333                        Married             Wife       NaN
# 15370                        Married             Wife       NaN
# 15397                         Single     Other Family       NaN
# 15455                       Divorced            Alone       NaN
# 15506                        Married             Wife       NaN
# 15562                         Single  Other relatives       NaN
# 15652                         Single  Other relatives       NaN
# 15711                        Married             Wife       NaN
# 15876                         Single         Children       NaN
# 15884                         Single     Other Family       NaN
# 15922       Married - Spouse Missing     Other Family       NaN
# 15954                        Married             Wife       NaN
# 16024                         Single            Alone       NaN
# 16028                        Married             Wife       NaN
# 16056                        Married             Wife       NaN
# 16057                        Married             Wife       NaN
# 16111                        Married          Husband       NaN
# 16169                       Divorced     Other Family       NaN
# 16183                        Married             Wife       NaN
# 16196                         Single  Other relatives       NaN
# 16254                        Married             Wife       NaN
# 16257                        Married             Wife       NaN
# 16322                        Married             Wife       NaN
# 16338                        Married             Wife       NaN
# 16394                        Married             Wife       NaN
# 16424                       Divorced     Other Family       NaN
# 16456                          Widow     Other Family       NaN
# 16503                        Married             Wife       NaN
# 16588                        Married             Wife       NaN
# 16597                       Divorced     Other Family       NaN
# 16627                         Single  Other relatives       NaN
# 16659                         Single         Children       NaN
# 16763                        Married          Husband       NaN
# 16885                         Single  Other relatives       NaN
# 16905                        Married             Wife       NaN
# 16922                        Married             Wife       NaN
# 17027                       Divorced     Other Family       NaN
# 17121                         Single     Other Family       NaN
# 17222                        Married          Husband       NaN
# 17227                        Married             Wife       NaN
# 17278                      Separated            Alone       NaN
# 17282                         Single     Other Family       NaN
# 17360                         Single     Other Family       NaN
# 17449                       Divorced     Other Family       NaN
# 17470                         Single  Other relatives       NaN
# 17488                         Single         Children       NaN
# 17582                        Married          Husband       NaN
# 17602                        Married          Husband       NaN
# 17715                      Separated            Alone       NaN
# 17719                         Single         Children       NaN
# 17763                         Single            Alone       NaN
# 17770                        Married             Wife       NaN
# 17863                         Single     Other Family       NaN
# 17974                         Single            Alone       NaN
# 18062                         Single     Other Family       NaN
# 18083                       Divorced            Alone       NaN
# 18084                        Married             Wife       NaN
# 18118                         Single  Other relatives       NaN
# 18135                         Single  Other relatives       NaN
# 18149                        Married          Husband       NaN
# 18209                        Married             Wife       NaN
# 18409       Married - Spouse Missing     Other Family       NaN
# 18433                        Married             Wife       NaN
# 18563                         Single            Alone       NaN
# 18696                      Separated     Other Family       NaN
# 18708                         Single         Children       NaN
# 18755                        Married             Wife       NaN
# 18766                        Married             Wife       NaN
# 18814                         Single     Other Family       NaN
# 18827                        Married             Wife       NaN
# 18828                      Separated     Other Family       NaN
# 18866                       Divorced     Other Family       NaN
# 19164                         Single     Other Family       NaN
# 19291                         Single     Other Family       NaN
# 19322                        Married             Wife       NaN
# 19341                          Widow     Other Family       NaN
# 19392                        Married             Wife       NaN
# 19400                        Married             Wife       NaN
# 19424                        Married             Wife       NaN
# 19447                         Single     Other Family       NaN
# 19543                        Married             Wife       NaN
# 19661                       Divorced            Alone       NaN
# 19698                       Divorced            Alone       NaN
# 19771                        Married             Wife       NaN
# 19809                         Single            Alone       NaN
# 19811                         Single     Other Family       NaN
# 19869                        Married             Wife       NaN
# 19964                      Separated            Alone       NaN
# 20024                         Single     Other Family       NaN
# 20045                        Married             Wife       NaN
# 20052                       Divorced            Alone       NaN
# 20084                        Married             Wife       NaN
# 20194                       Divorced            Alone       NaN
# 20216                        Married             Wife       NaN
# 20219                         Single            Alone       NaN
# 20246                        Married             Wife       NaN
# 20269                      Separated     Other Family       NaN
# 20342                        Married             Wife       NaN
# 20410                        Married             Wife       NaN
# 20456                        Married             Wife       NaN
# 20462                        Married             Wife       NaN
# 20619                          Widow            Alone       NaN
# 20628                        Married             Wife       NaN
# 20730                      Separated     Other Family       NaN
# 20756                        Married          Husband       NaN
# 20760                      Separated            Alone       NaN
# 20789                          Widow            Alone       NaN
# 20848                       Divorced            Alone       NaN
# 20855                         Single     Other Family       NaN
# 20966                        Married             Wife       NaN
# 20974                        Married             Wife       NaN
# 20983                        Married             Wife       NaN
# 21014                        Married             Wife       NaN
# 21021                         Single     Other Family       NaN
# 21097                         Single     Other Family       NaN
# 21165                         Single     Other Family       NaN
# 21218                        Married             Wife       NaN
# 21257                        Married             Wife       NaN
# 21269       Married - Spouse Missing     Other Family       NaN
# 21278                         Single  Other relatives       NaN
# 21282                         Single     Other Family       NaN
# 21350                        Married             Wife       NaN
# 21358                       Divorced     Other Family       NaN
# 21372                          Widow            Alone       NaN
# 21404                        Married             Wife       NaN
# 21406                         Single     Other Family       NaN
# 21446                         Single     Other Family       NaN
# 21457                        Married             Wife       NaN
# 21506                         Single         Children       NaN
# 21564                        Married             Wife       NaN
# 21586                         Single         Children       NaN
# 21812                       Divorced  Other relatives       NaN
# 21931                       Divorced     Other Family       NaN
# 21947                        Married             Wife       NaN
# 21965                         Single     Other Family       NaN
# 22171                        Married             Wife       NaN
# 22392       Married - Spouse Missing     Other Family       NaN
# 22566                        Married             Wife       NaN
# 22569                        Married             Wife       NaN
# 22591                        Married             Wife       NaN
# 22624                         Single     Other Family       NaN
# 22628                        Married             Wife       NaN
# 22655                         Single     Other Family       NaN
# 22699                       Divorced     Other Family       NaN
# 22739                         Single         Children       NaN
# 22854                         Single     Other Family       NaN
# 22920                        Married             Wife       NaN
# 22996                      Separated     Other Family       NaN
# 23079                         Single            Alone       NaN
# 23126                      Separated            Alone       NaN
# 23130                        Married             Wife       NaN
# 23234                        Married             Wife       NaN
# 23257                       Divorced     Other Family       NaN
# 23273                        Married             Wife       NaN
# 23308                         Single         Children       NaN
# 23336                         Single     Other Family       NaN
# 23406                         Single     Other Family       NaN
# 23411                        Married          Husband       NaN
# 23521                       Divorced            Alone       NaN
# 23522                         Single         Children       NaN
# 23528                         Single     Other Family       NaN
# 23690                        Married             Wife       NaN
# 23756                         Single         Children       NaN
# 23850                        Married             Wife       NaN
# 23858                         Single         Children       NaN
# 23949                        Married             Wife       NaN
# 23979                        Married             Wife       NaN
# 24112                         Single         Children       NaN
# 24163       Married - Spouse Missing            Alone       NaN
# 24209                        Married             Wife       NaN
# 24226                         Single     Other Family       NaN
# 24416                         Single  Other relatives       NaN
# 24470                         Single     Other Family       NaN
# 24543                         Single  Other relatives       NaN
# 24776                       Divorced     Other Family       NaN
# 24789                        Married             Wife       NaN
# 24793                        Married             Wife       NaN
# 24821                        Married             Wife       NaN
# 24892                        Married             Wife       NaN
# 24905                        Married             Wife       NaN
# 24948                         Single     Other Family       NaN
# 25166                         Single  Other relatives       NaN
# 25386                       Divorced     Other Family       NaN
# 25448                         Single     Other Family       NaN
# 25500                        Married             Wife       NaN
# 25533                        Married             Wife       NaN
# 25569                         Single  Other relatives       NaN
# 25607                        Married             Wife       NaN
# 25699                        Married             Wife       NaN
# 25707                        Married             Wife       NaN
# 25742                         Single     Other Family       NaN
# 25750                        Married             Wife       NaN
# 25789                         Single     Other Family       NaN
# 25839                        Married             Wife       NaN
# 25854                          Widow     Other Family       NaN
# 25868                        Married             Wife       NaN
# 25944                        Married             Wife       NaN
# 25954                        Married             Wife       NaN
# 26006                        Married             Wife       NaN
# 26008                        Married             Wife       NaN
# 26052                      Separated     Other Family       NaN
# 26145                        Married             Wife       NaN
# 26234                        Married             Wife       NaN
# 26251                         Single     Other Family       NaN
# 26321       Married - Spouse Missing  Other relatives       NaN
# 26396                        Married          Husband       NaN
# 26475                         Single         Children       NaN
# 26684                         Single            Alone       NaN
# 26709                        Married          Husband       NaN
# 26761                         Single     Other Family       NaN
# 26827                         Single         Children       NaN
# 26835                        Married             Wife       NaN
# 26854                         Single     Other Family       NaN
# 27086                         Single            Alone       NaN
# 27173                        Married          Husband       NaN
# 27208                        Married             Wife       NaN
# 27216                         Single         Children       NaN
# 27266                         Single     Other Family       NaN
# 27335                        Married             Wife       NaN
# 27353                        Married             Wife       NaN
# 27382                         Single         Children       NaN
# 27418                         Single     Other Family       NaN
# 27532                        Married             Wife       NaN
# 27568                         Single     Other Family       NaN
# 27593                         Single     Other Family       NaN
# 27599                         Single         Children       NaN
# 27653                        Married             Wife       NaN
# 27671                         Single            Alone       NaN
# 27673                        Married             Wife       NaN
# 27683                        Married             Wife       NaN
# 27838                       Divorced            Alone       NaN
# 27869                         Single         Children       NaN
# 27991                       Divorced            Alone       NaN
# 28197                        Married          Husband       NaN
# 28319                        Married             Wife       NaN
# 28331                        Married             Wife       NaN
# 28352                          Widow            Alone       NaN
# 28392                         Single         Children       NaN
# 28411                        Married             Wife       NaN
# 28430                         Single     Other Family       NaN
# 28437                       Divorced            Alone       NaN
# 28438                        Married             Wife       NaN
# 28508                        Married             Wife       NaN
# 28541                       Divorced     Other Family       NaN
# 28584                      Separated     Other Family       NaN
# 28604                          Widow     Other Family       NaN
# 28607                        Married             Wife       NaN
# 28681                        Married             Wife       NaN
# 28683       Married - Spouse Missing  Other relatives       NaN
# 28684                        Married             Wife       NaN
# 28746                        Married             Wife       NaN
# 28779       Married - Spouse Missing     Other Family       NaN
# 28827                         Single     Other Family       NaN
# 28828                        Married             Wife       NaN
# 28834                         Single         Children       NaN
# 28847                        Married             Wife       NaN
# 28869                        Married             Wife       NaN
# 28900                       Divorced     Other Family       NaN
# 28929       Married - Spouse Missing     Other Family       NaN
# 28946                       Divorced     Other Family       NaN
# ...
# 20789                           40               0             0
# 20848                           40               0             0
# 20855                           99               0             0
# 20966                           40               0             0
# 20974                           50               0             0
# 20983                           40               0             0
# 21014                           48               0             0
# 21021                           32               0             0
# 21097                           20               0             0
# 21165                           55           16667             0
# 21218                           40               0             0
# 21257                           50           18480             0
# 21269                           60               0             0
# 21278                           40               0             0
# 21282                           40               0             0
# 21350                           40               0             0
# 21358                           45               0             0
# 21372                           40               0             0
# 21404                           45               0             0
# 21406                           30               0             0
# 21446                           40               0             0
# 21457                           45               0             0
# 21506                           40               0             0
# 21564                           35               0             0
# 21586                           12               0             0
# 21812                           40            9712             0
# 21931                           40               0             0
# 21947                           40               0             0
# 21965                           36               0             0
# 22171                           70               0             0
# 22392                           50               0             0
# 22566                           40               0             0
# 22569                           60               0             0
# 22591                           66               0             0
# 22624                           40               0             0
# 22628                           25               0             0
# 22655                           40               0             0
# 22699                           60               0             0
# 22739                           40               0             0
# 22854                           40               0             0
# 22920                           42               0          2924
# 22996                           40               0             0
# 23079                           40               0             0
# 23126                           40               0             0
# 23130                           40               0             0
# 23234                           40            4849             0
# 23257                           60               0          2053
# 23273                           40               0             0
# 23308                           40               0             0
# 23336                           40               0             0
# 23406                           20               0             0
# 23411                           40            4261             0
# 30794                           40               0             0
# 30824                           40               0             0
# 31321                           30            2708             0
# 31334                           40               0             0
# 31370                           44               0             0
# 31380                           40               0             0
# 31464                           40               0             0
# 31508                           50           18480             0
# 31667                           50               0             0
# 31764                           28               0             0
# 31807                           15               0             0
# 31879                           50               0             0
# 31955                           35               0             0
# 32080                           40               0             0
# 32160                           40               0             0
# 32281                           40               0             0
# 32337                           12               0             0
# 32402                           40               0             0
# 32405                            4               0             0
# 32416                           40               0             0
# 32447                           45               0             0
# 32498                           20               0             0
# 32720                           40               0             0
# 32914                           40               0             0
# 32992                           40               0          1732
# 33051                           45               0             0
# 33065                           30               0             0
# 33247                           40               0             0
# 33270                           35               0             0
# 33306                           60               0          2339
# 33400                           50               0             0
# 33524                           40          122999             0
# 33575                           55               0          1827
# 33634                           45               0             0
# 33679                           60               0             0
# 33710                           25          122999             0
# 33719                           70               0          2970
# 33724                           35               0             0
# 33783                           40               0             0
# 33833                            5               0          2002
# 33842                           40               0             0
# 33893                           13               0             0
# 33905                           40               0          1956
# 33932                           48               0             0
# 34040                           40               0             0
# 34111                           15               0             0
# 34119                           40               0             0
# 34154                           35               0             0
# 34322                           25               0             0
# 34383                           60               0             0
# 34423                           80               0             0
# 34436                           40               0             0
# 34497                           40               0             0
# 34527                           36               0             0
# 34533                           40               0             0
# 34630                           40               0          2339
# 34728                           30               0             0
# 34835                           40               0             0
# 34859                           40               0          2321

# %%
df_train2=impute_mode_by_cat('Base Area')
# Out:
# <ipython-input-123-79cd64ba2945>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp[col][i]=gr[x]
# <ipython-input-123-79cd64ba2945>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp[col][i]=df_train2[col].mode()[0]

# %%
df_train2[df_train2['Employment Sector'].isnull()]
# Out:
#                               Name   Birthday Native Continent  \
# CITIZEN_ID
# 12508       Miss Gabrielle Cameron 2028-02-09           Europe
# 12511           Miss Amy Churchill 2029-02-10           Europe
# 12523        Mr. William Sanderson 1997-10-08           Europe
# 12529           Miss Deirdre Lyman 2018-03-28             Asia
# 12530          Mrs. Carolyn Tucker 1976-02-03           Europe
# ...                            ...        ...              ...
# 34795               Mr. Luke Smith 1985-03-05           Europe
# 34814           Mr. Stewart Newman 1990-01-23          America
# 34823          Mr. Jonathan Slater 2006-05-27           Europe
# 34825           Mr. Steven Vaughan 1995-06-27           Europe
# 34856              Mr. Neil Butler 2031-05-21           Europe
#
#                       Marital Status       Lives with     Base Area  \
# CITIZEN_ID
# 12508                         Single  Other relatives     Northbury
# 12511                         Single         Children     Northbury
# 12523                        Married             Wife     Northbury
# 12529                         Single     Other Family  Knife's Edge
# 12530                          Widow     Other Family     Northbury
# ...                              ...              ...           ...
# 34795                        Married             Wife     Northbury
# 34814       Married - Spouse Missing            Alone     Northbury
# 34823                        Married             Wife     Northbury
# 34825                        Married             Wife     Northbury
# 34856                         Single         Children     Northbury
#
#                          Education Level  Years of Education  \
# CITIZEN_ID
# 12508                Professional School                  12
# 12511       High School + PostGraduation                  13
# 12523                            Masters                  17
# 12529         Bachelors + PostGraduation                  16
# 12530            High School - 2nd Cycle                  11
# ...                                  ...                 ...
# 34795                Professional School                  12
# 34814                     Primary School                   4
# 34823       High School + PostGraduation                  13
# 34825                Professional School                  12
# 34856            High School - 1st Cycle                  10
#
#            Employment Sector Role  Working Hours per week  Money Received  \
# CITIZEN_ID
# 12508                    NaN  NaN                      35               0
# 12511                    NaN  NaN                      40               0
# 12523                    NaN  NaN                      40               0
# 12529                    NaN  NaN                      50               0
# 12530                    NaN  NaN                      24               0
# ...                      ...  ...                     ...             ...
# 34795                    NaN  NaN                      20               0
# 34814                    NaN  NaN                      40               0
# 34823                    NaN  NaN                      60               0
# 34825                    NaN  NaN                      40               0
# 34856                    NaN  NaN                      30               0
#
#             Ticket Price
# CITIZEN_ID
# 12508                  0
# 12511                  0
# 12523                  0
# 12529                  0
# 12530                  0
# ...                  ...
# 34795                  0
# 34814                  0
# 34823                  0
# 34825                  0
# 34856                  0
#
# [1264 rows x 13 columns]

# %%
df_train2=impute_mode_by_cat('Employment Sector')
# Out:
# <ipython-input-123-79cd64ba2945>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp[col][i]=gr[x]
# <ipython-input-123-79cd64ba2945>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp[col][i]=df_train2[col].mode()[0]

# %%
df_train2[df_train2['Role'].isnull()]
# Out:
#                               Name   Birthday Native Continent  \
# CITIZEN_ID
# 12508       Miss Gabrielle Cameron 2028-02-09           Europe
# 12511           Miss Amy Churchill 2029-02-10           Europe
# 12523        Mr. William Sanderson 1997-10-08           Europe
# 12529           Miss Deirdre Lyman 2018-03-28             Asia
# 12530          Mrs. Carolyn Tucker 1976-02-03           Europe
# ...                            ...        ...              ...
# 34795               Mr. Luke Smith 1985-03-05           Europe
# 34814           Mr. Stewart Newman 1990-01-23          America
# 34823          Mr. Jonathan Slater 2006-05-27           Europe
# 34825           Mr. Steven Vaughan 1995-06-27           Europe
# 34856              Mr. Neil Butler 2031-05-21           Europe
#
#                       Marital Status       Lives with     Base Area  \
# CITIZEN_ID
# 12508                         Single  Other relatives     Northbury
# 12511                         Single         Children     Northbury
# 12523                        Married             Wife     Northbury
# 12529                         Single     Other Family  Knife's Edge
# 12530                          Widow     Other Family     Northbury
# ...                              ...              ...           ...
# 34795                        Married             Wife     Northbury
# 34814       Married - Spouse Missing            Alone     Northbury
# 34823                        Married             Wife     Northbury
# 34825                        Married             Wife     Northbury
# 34856                         Single         Children     Northbury
#
#                          Education Level  Years of Education  \
# CITIZEN_ID
# 12508                Professional School                  12
# 12511       High School + PostGraduation                  13
# 12523                            Masters                  17
# 12529         Bachelors + PostGraduation                  16
# 12530            High School - 2nd Cycle                  11
# ...                                  ...                 ...
# 34795                Professional School                  12
# 34814                     Primary School                   4
# 34823       High School + PostGraduation                  13
# 34825                Professional School                  12
# 34856            High School - 1st Cycle                  10
#
#                      Employment Sector Role  Working Hours per week  \
# CITIZEN_ID
# 12508       Private Sector - Services   NaN                      35
# 12511       Private Sector - Services   NaN                      40
# 12523       Private Sector - Services   NaN                      40
# 12529       Private Sector - Services   NaN                      50
# 12530       Private Sector - Services   NaN                      24
# ...                                ...  ...                     ...
# 34795       Private Sector - Services   NaN                      20
# 34814       Private Sector - Services   NaN                      40
# 34823       Private Sector - Services   NaN                      60
# 34825       Private Sector - Services   NaN                      40
# 34856       Private Sector - Services   NaN                      30
#
#             Money Received  Ticket Price
# CITIZEN_ID
# 12508                    0             0
# 12511                    0             0
# 12523                    0             0
# 12529                    0             0
# 12530                    0             0
# ...                    ...           ...
# 34795                    0             0
# 34814                    0             0
# 34823                    0             0
# 34825                    0             0
# 34856                    0             0
#
# [1264 rows x 13 columns]

# %%
df_train2=impute_mode_by_cat('Role')
# Out:
# <ipython-input-123-79cd64ba2945>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp[col][i]=gr[x]
# <ipython-input-123-79cd64ba2945>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp[col][i]=df_train2[col].mode()[0]

# %%
df_train2.isna().sum()
# Out:
# Name                      0
# Birthday                  0
# Native Continent          0
# Marital Status            0
# Lives with                0
# Base Area                 0
# Education Level           0
# Years of Education        0
# Employment Sector         0
# Role                      0
# Working Hours per week    0
# Money Received            0
# Ticket Price              0
# dtype: int64

# %%
# Funciona
sns.set_style("whitegrid")
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(25,25))


axa=sns.countplot(df_train2["Base Area"], ax=axes[0,1])
axb=sns.countplot(df_train2["Employment Sector"], ax=axes[1,1])
axc=sns.countplot(df_train2["Role"], ax=axes[2,1])

ax4=sns.countplot(non_metric["Base Area"], ax=axes[0,0])
ax5=sns.countplot(non_metric["Employment Sector"], ax=axes[1,0])
ax7=sns.countplot(non_metric["Role"], ax=axes[2, 0])


axa.tick_params(labelsize=15)
axa.set_xticklabels(axa.get_xticklabels(), rotation=90)
axa.set_xlabel(xlabel='Base Area',fontsize = 17)
axa.set_ylabel(ylabel='Nr of observations',fontsize = 17)
axa.set(ylim=(0, 21000))

ax4.tick_params(labelsize=15)
ax4.set_xticklabels(ax4.get_xticklabels(), rotation=90)
ax4.set_xlabel(xlabel='Base Area - with missings',fontsize = 17)
ax4.set_ylabel(ylabel='Nr of observations',fontsize = 17)
ax4.set(ylim=(0, 21000))

axb.tick_params(labelsize=15)
axb.set_xticklabels(axb.get_xticklabels(), rotation=90)
axb.set_xlabel(xlabel='Employment Sector',fontsize = 17)
axb.set_ylabel(ylabel='Nr of observations',fontsize = 17)
axb.set(ylim=(0, 17000))

ax5.tick_params(labelsize=15)
ax5.set_xticklabels(ax5.get_xticklabels(), rotation=90)
ax5.set_xlabel(xlabel='Employment Sector - with missings',fontsize = 17)
ax5.set_ylabel(ylabel='Nr of observations',fontsize = 17)
ax5.set(ylim=(0, 17000))

axc.tick_params(labelsize=15)
axc.set_xticklabels(axc.get_xticklabels(), rotation=90)
axc.set_xlabel(xlabel='Role',fontsize = 17)
axc.set_ylabel(ylabel='Nr of observations',fontsize = 17)
axc.set(ylim=(0, 3200))

ax7.tick_params(labelsize=15)
ax7.set_xticklabels(ax7.get_xticklabels(), rotation=90)
ax7.set_xlabel(xlabel='Role - with missings',fontsize = 17)
ax7.set_ylabel(ylabel='Nr of observations',fontsize = 17)
ax7.set(ylim=(0, 3200))

plt.subplots_adjust(top=0.9,hspace=0.9)
plt.suptitle("Distribution of variables with and without missing values", fontsize=30)
# Out:
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Mariana/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 0.98, 'Distribution of variables with and without missing values')

# %% [markdown]
# ## Feature Engineering

# %%
#EXPLICARRR

# New variable for Age
from datetime import datetime
df_train2["Age"]=df_train2.Birthday.map(lambda x: datetime.now().year+28-x.year)

# %%
df_train2[["Birthday","Age"]]
# Out:
#              Birthday  Age
# CITIZEN_ID
# 12486      2003-07-01   45
# 12487      2006-01-25   42
# 12488      2009-05-10   39
# 12489      1985-03-25   63
# 12490      2015-05-29   33
# ...               ...  ...
# 34881      2023-03-15   25
# 34882      2025-03-07   23
# 34883      2022-07-20   26
# 34884      2011-06-11   37
# 34885      2026-10-02   22
#
# [22400 rows x 2 columns]

# %%
# New variable for Gender - binary if it's a male or not
df_train2['Male'] = np.where(df_train2.Name.str.contains('Mrs|Miss'), '0', '1')

# %%
# Check the values for variable Marital Status
df_train2["Marital Status"].unique()
# Out:
# array(['Married', 'Single', 'Married - Spouse Missing', 'Divorced',
#        'Separated', 'Widow', 'Married - Spouse in the Army'], dtype=object)

# %%
#In column Marital Status, join "Married" with 'Married - Spouse Missing' and 'Married - Spouse in the Army' since we do not consider this distintion relevant
df_train2["Marital Status_new"]=df_train2["Marital Status"]
df_train2["Marital Status_new"][(df_train2["Marital Status"].str.contains("Married")==True) & (df_train2["Marital Status"]!="Married")]="Married"

#In column Marital Status, join "Divorced" with 'Separated' in "Divorced or Separated"
df_train2["Marital Status_new"][(df_train2["Marital Status"]=="Separated") | (df_train2["Marital Status"]=="Divorced")]="Divorced or Separated"

df_train2["Marital Status_new"][(df_train2["Marital Status"]=="Married")]
# Out:
# <ipython-input-135-d3808c6b0aad>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2["Marital Status_new"][(df_train2["Marital Status"].str.contains("Married")==True) & (df_train2["Marital Status"]!="Married")]="Married"
# <ipython-input-135-d3808c6b0aad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2["Marital Status_new"][(df_train2["Marital Status"]=="Separated") | (df_train2["Marital Status"]=="Divorced")]="Divorced or Separated"
# CITIZEN_ID
# 12486    Married
# 12487    Married
# 12488    Married
# 12489    Married
# 12492    Married
#           ...
# 34876    Married
# 34877    Married
# 34878    Married
# 34879    Married
# 34880    Married
# Name: Marital Status_new, Length: 10219, dtype: object

# %%
# New binary variable to determine whether the person is married
df_train2["Is Married"]=0
df_train2["Is Married"][(df_train2["Marital Status_new"]=="Married")]=1
# Out:
# <ipython-input-136-6b0578b734da>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2["Is Married"][(df_train2["Marital Status_new"]=="Married")]=1

# %%
df_train2["Marital Status_new"].unique()
# Out:
# array(['Married', 'Single', 'Divorced or Separated', 'Widow'],
#       dtype=object)

# %%
df_train2["Is Married"]
# Out:
# CITIZEN_ID
# 12486    1
# 12487    1
# 12488    1
# 12489    1
# 12490    0
#         ..
# 34881    0
# 34882    0
# 34883    0
# 34884    0
# 34885    0
# Name: Is Married, Length: 22400, dtype: int64

# %%
# Check the values for variable Education Level
df_train2["Education Level"].unique()
# Out:
# array(['High School + PostGraduation', 'Professional School',
#        'High School - 2nd Cycle', 'PhD', 'Bachelors',
#        'Bachelors + PostGraduation', 'Masters', 'High School - 1st Cycle',
#        'High School Complete', 'Masters + PostGraduation',
#        'Professional School + PostGraduation',
#        'Middle School - 2nd Cycle', 'Middle School Complete',
#        'Middle School - 1st Cycle', 'Primary School',
#        'No Relevant Education'], dtype=object)

# %%
#In column Education Level, join all equal periods of education level

df_train2["Education Level_new"]=df_train2["Education Level"]

df_train2["Education Level_new"][(df_train2["Education Level"]=="Middle School - 1st Cycle") |
                    (df_train2["Education Level"]=="Middle School - 2nd Cycle")|
                    (df_train2["Education Level"]=="Middle School Complete")]="Middle School"

df_train2["Education Level_new"][(df_train2["Education Level"]=="High School - 1st Cycle") | 
                    (df_train2["Education Level"]=="High School - 2nd Cycle") | 
                    (df_train2["Education Level"]=="High School Complete")]="High School"
# Out:
# <ipython-input-140-949cf134105c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2["Education Level_new"][(df_train2["Education Level"]=="Middle School - 1st Cycle") |
# <ipython-input-140-949cf134105c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2["Education Level_new"][(df_train2["Education Level"]=="High School - 1st Cycle") |

# %%
df_train2["Education Level_new"].unique()
# Out:
# array(['High School + PostGraduation', 'Professional School',
#        'High School', 'PhD', 'Bachelors', 'Bachelors + PostGraduation',
#        'Masters', 'Masters + PostGraduation',
#        'Professional School + PostGraduation', 'Middle School',
#        'Primary School', 'No Relevant Education'], dtype=object)

# %%
df_train2["Years of Education"][df_train2["Education Level_new"]=='Professional School'].unique()
# Out:
# array([12])

# %%
df_train2["Years of Education"][df_train2["Education Level_new"]=='High School']
# Out:
# CITIZEN_ID
# 12489    11
# 12493    11
# 12505    10
# 12512    12
# 12524    11
#          ..
# 34847    11
# 34856    10
# 34857    12
# 34858    10
# 34865    11
# Name: Years of Education, Length: 1745, dtype: int64

# %%
#Join all without considering Post Graduation

df_train2["Education Level_new2"]=df_train2["Education Level_new"].copy()
df_train2["Education Level_new2"][(df_train2["Education Level_new2"]=="High School + PostGraduation")]="High School"
df_train2["Education Level_new2"][(df_train2["Education Level_new2"]=="Bachelors + PostGraduation")]="Bachelors"
df_train2["Education Level_new2"][(df_train2["Education Level_new2"]=="Professional School + PostGraduation")]="Professional School"
df_train2["Education Level_new2"][(df_train2["Education Level_new2"]=="Masters + PostGraduation")]="Masters"
df_train2[["Education Level_new", "Education Level_new2"]]
# Out:
# <ipython-input-144-4d90ae3416be>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2["Education Level_new2"][(df_train2["Education Level_new2"]=="High School + PostGraduation")]="High School"
# <ipython-input-144-4d90ae3416be>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2["Education Level_new2"][(df_train2["Education Level_new2"]=="Bachelors + PostGraduation")]="Bachelors"
# <ipython-input-144-4d90ae3416be>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2["Education Level_new2"][(df_train2["Education Level_new2"]=="Professional School + PostGraduation")]="Professional School"
# <ipython-input-144-4d90ae3416be>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2["Education Level_new2"][(df_train2["Education Level_new2"]=="Masters + PostGraduation")]="Masters"
#                      Education Level_new Education Level_new2
# CITIZEN_ID
# 12486       High School + PostGraduation          High School
# 12487                Professional School  Professional School
# 12488                Professional School  Professional School
# 12489                        High School          High School
# 12490                                PhD                  PhD
# ...                                  ...                  ...
# 34881                Professional School  Professional School
# 34882                Professional School  Professional School
# 34883                            Masters              Masters
# 34884         Bachelors + PostGraduation            Bachelors
# 34885       High School + PostGraduation          High School
#
# [22400 rows x 2 columns]

# %%
#Binary that says if the citizen has Post Graduation or not

df_train2["PostGraduation"]=df_train2["Education Level_new"].map(lambda x: 1 if "+" in x else 0)
df_train2["PostGraduation"]
# Out:
# CITIZEN_ID
# 12486    1
# 12487    0
# 12488    0
# 12489    0
# 12490    0
#         ..
# 34881    0
# 34882    0
# 34883    0
# 34884    1
# 34885    1
# Name: PostGraduation, Length: 22400, dtype: int64

# %%
# New binary variable related to Higher Education
# (includes at least one of the following: Post Graduation, Bachelors, Masters, PhD)

df_train2['Higher Education']=np.where(df_train2['Years of Education']>12, '1', '0')

# %%
# New binary variable that tells us if each person lives in the capital city or not
df_train2['Capital']= np.where(df_train2['Base Area']=='Northbury', '1', '0')

# %%
# New binary variable to determine whether the person belongs to Group B (people who were payed to participate in the mission)
df_train2['Group B']=np.where(df_train2['Money Received']!=0, '1', '0')

# %%
# New binary variable to determine whether the person belongs to Group C (people who payed to participate in the mission)
df_train2['Group C']=np.where(df_train2['Ticket Price']!=0, '1', '0')

# %%
df_train2.head()
# Out:
#                             Name   Birthday Native Continent Marital Status  \
# CITIZEN_ID
# 12486            Mr. Adam Glover 2003-07-01           Europe        Married
# 12487       Mr. Cameron McDonald 2006-01-25           Europe        Married
# 12488         Mr. Keith Davidson 2009-05-10           Europe        Married
# 12489         Mr. Alexander Gill 1985-03-25           Europe        Married
# 12490             Mr. Neil Piper 2015-05-29           Europe         Single
#
#               Lives with  Base Area               Education Level  \
# CITIZEN_ID
# 12486               Wife  Northbury  High School + PostGraduation
# 12487               Wife  Northbury           Professional School
# 12488               Wife  Northbury           Professional School
# 12489               Wife  Northbury       High School - 2nd Cycle
# 12490       Other Family  Northbury                           PhD
#
#             Years of Education           Employment Sector  \
# CITIZEN_ID
# 12486                       13  Private Sector - Services
# 12487                       12      Public Sector - Others
# 12488                       12  Private Sector - Services
# 12489                       11  Private Sector - Services
# 12490                       21  Self-Employed (Individual)
#
#                               Role  ...  Male  Marital Status_new  Is Married  \
# CITIZEN_ID                          ...
# 12486       Repair & constructions  ...     1             Married           1
# 12487       Repair & constructions  ...     1             Married           1
# 12488                        Sales  ...     1             Married           1
# 12489                     Security  ...     1             Married           1
# 12490                    Professor  ...     1              Single           0
#
#                      Education Level_new Education Level_new2 PostGraduation  \
# CITIZEN_ID
# 12486       High School + PostGraduation          High School              1
# 12487                Professional School  Professional School              0
# 12488                Professional School  Professional School              0
# 12489                        High School          High School              0
# 12490                                PhD                  PhD              0
#
#             Higher Education Capital Group B  Group C
# CITIZEN_ID
# 12486                      1       1       0        1
# 12487                      0       1       0        0
# 12488                      0       1       0        1
# 12489                      0       1       1        0
# 12490                      1       1       0        0
#
# [5 rows x 24 columns]

# %%
# publico ou privado ou self ou uneployed empl. sector
def sectors(a):
    if 'Private Sector' in a:
        return 'Private Sector'
    elif 'Public Sector' in a:
        return 'Public Sector'
    elif 'Self-Employed' in a:
        return 'Self-Employed'
    else:
        return 'Unemployed / Never Worked'
    
df_train2['Employment Sector (simplified)'] = df_train2['Employment Sector'].map(sectors)

# %%
# binaria governo ou n empl. sector
df_train2['Government'] = df_train2['Employment Sector'].map(lambda x: 1 if 'Government' in x else 0)

# %%
df_train2.columns
# Out:
# Index(['Name', 'Birthday', 'Native Continent', 'Marital Status', 'Lives with',
#        'Base Area', 'Education Level', 'Years of Education',
#        'Employment Sector', 'Role', 'Working Hours per week', 'Money Received',
#        'Ticket Price', 'Age', 'Male', 'Marital Status_new', 'Is Married',
#        'Education Level_new', 'Education Level_new2', 'PostGraduation',
#        'Higher Education', 'Capital', 'Group B', 'Group C',
#        'Employment Sector (simplified)', 'Government'],
#       dtype='object')

# %%
from sklearn import preprocessing

x = df_train2[["Ticket Price", "Money Received"]].values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df= pd.DataFrame(x_scaled)

# %%
sns.histplot(df[0][df[0]!=0])

# %%
sns.histplot(df[1][df[1]!=0])

# %%
Median_Money_Received=df_train2["Money Received"][df_train2["Money Received"]>0].median()
Median_Ticket_Price=df_train2["Ticket Price"][df_train2["Ticket Price"]>0].median()

df_train2['Money Relevance']=0
df_train2['Money Relevance'][df_train2["Money Received"]> Median_Money_Received] =1
df_train2['Money Relevance'][(df_train2["Money Received"]<= Median_Money_Received) & (df_train2["Money Received"]>0)]=2

df_train2['Money Relevance'][df_train2["Ticket Price"]> Median_Ticket_Price] =5
df_train2['Money Relevance'][(df_train2["Ticket Price"]<= Median_Ticket_Price) & (df_train2["Ticket Price"]>0)] =4

df_train2['Money Relevance'][(df_train2["Ticket Price"]== 0) & (df_train2["Money Received"]==0)] =3
# Out:
# <ipython-input-157-2b30f458841b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2['Money Relevance'][df_train2["Money Received"]> Median_Money_Received] =1
# <ipython-input-157-2b30f458841b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2['Money Relevance'][(df_train2["Money Received"]<= Median_Money_Received) & (df_train2["Money Received"]>0)]=2
# <ipython-input-157-2b30f458841b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2['Money Relevance'][df_train2["Ticket Price"]> Median_Ticket_Price] =5
# <ipython-input-157-2b30f458841b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2['Money Relevance'][(df_train2["Ticket Price"]<= Median_Ticket_Price) & (df_train2["Ticket Price"]>0)] =4
# <ipython-input-157-2b30f458841b>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train2['Money Relevance'][(df_train2["Ticket Price"]== 0) & (df_train2["Money Received"]==0)] =3

# %%
df_train2[["Ticket Price", "Money Received", "Money Relevance"]]
# Out:
#             Ticket Price  Money Received  Money Relevance
# CITIZEN_ID
# 12486               2273               0                4
# 12487                  0               0                3
# 12488               2321               0                4
# 12489                  0            5395                2
# 12490                  0               0                3
# ...                  ...             ...              ...
# 34881                  0               0                3
# 34882                  0               0                3
# 34883                  0            2674                2
# 34884                  0               0                3
# 34885                  0               0                3
#
# [22400 rows x 3 columns]

# %%
#df_train2.drop(columns=["Ticket Price", "Money Received"]), inplace=True)

# %% [markdown]
# ## Feature Selection

# %%
df_train2
# Out:
#                              Name   Birthday Native Continent Marital Status  \
# CITIZEN_ID
# 12486             Mr. Adam Glover 2003-07-01           Europe        Married
# 12487        Mr. Cameron McDonald 2006-01-25           Europe        Married
# 12488          Mr. Keith Davidson 2009-05-10           Europe        Married
# 12489          Mr. Alexander Gill 1985-03-25           Europe        Married
# 12490              Mr. Neil Piper 2015-05-29           Europe         Single
# ...                           ...        ...              ...            ...
# 34881             Mrs. Lisa Alsop 2023-03-15           Europe       Divorced
# 34882          Mr. Julian Coleman 2025-03-07           Europe         Single
# 34883          Miss Amelia Walker 2022-07-20           Europe         Single
# 34884       Mr. Justin Sutherland 2011-06-11           Europe         Single
# 34885           Mr. Joseph Murray 2026-10-02             Asia         Single
#
#               Lives with  Base Area               Education Level  \
# CITIZEN_ID
# 12486               Wife  Northbury  High School + PostGraduation
# 12487               Wife  Northbury           Professional School
# 12488               Wife  Northbury           Professional School
# 12489               Wife  Northbury       High School - 2nd Cycle
# 12490       Other Family  Northbury                           PhD
# ...                  ...        ...                           ...
# 34881           Children  Northbury           Professional School
# 34882           Children  Northbury           Professional School
# 34883       Other Family  Northbury                       Masters
# 34884       Other Family  Northbury    Bachelors + PostGraduation
# 34885           Children  Northbury  High School + PostGraduation
#
#             Years of Education           Employment Sector  \
# CITIZEN_ID
# 12486                       13  Private Sector - Services
# 12487                       12      Public Sector - Others
# 12488                       12  Private Sector - Services
# 12489                       11  Private Sector - Services
# 12490                       21  Self-Employed (Individual)
# ...                        ...                         ...
# 34881                       12  Private Sector - Services
# 34882                       12  Private Sector - Services
# 34883                       17      Public Sector - Others
# 34884                       16  Private Sector - Services
# 34885                       13  Private Sector - Services
#
#                               Role  ...           Education Level_new  \
# CITIZEN_ID                          ...
# 12486       Repair & constructions  ...  High School + PostGraduation
# 12487       Repair & constructions  ...           Professional School
# 12488                        Sales  ...           Professional School
# 12489                     Security  ...                   High School
# 12490                    Professor  ...                           PhD
# ...                            ...  ...                           ...
# 34881          Cleaners & Handlers  ...           Professional School
# 34882               Other services  ...           Professional School
# 34883                    Professor  ...                       Masters
# 34884       Repair & constructions  ...    Bachelors + PostGraduation
# 34885                   Transports  ...  High School + PostGraduation
#
#             Education Level_new2  PostGraduation  Higher Education Capital  \
# CITIZEN_ID
# 12486                High School               1                 1       1
# 12487        Professional School               0                 0       1
# 12488        Professional School               0                 0       1
# 12489                High School               0                 0       1
# 12490                        PhD               0                 1       1
# ...                          ...             ...               ...     ...
# 34881        Professional School               0                 0       1
# 34882        Professional School               0                 0       1
# 34883                    Masters               0                 1       1
# 34884                  Bachelors               1                 1       1
# 34885                High School               1                 1       1
#
#            Group B  Group C Employment Sector (simplified) Government  \
# CITIZEN_ID
# 12486            0        1                 Private Sector          0
# 12487            0        0                  Public Sector          0
# 12488            0        1                 Private Sector          0
# 12489            1        0                 Private Sector          0
# 12490            0        0                  Self-Employed          0
# ...            ...      ...                            ...        ...
# 34881            0        0                 Private Sector          0
# 34882            0        0                 Private Sector          0
# 34883            1        0                  Public Sector          0
# 34884            0        0                 Private Sector          0
# 34885            0        0                 Private Sector          0
#
#             Money Relevance
# CITIZEN_ID
# 12486                     4
# 12487                     3
# 12488                     4
# 12489                     2
# 12490                     3
# ...                     ...
# 34881                     3
# 34882                     3
# 34883                     2
# 34884                     3
# 34885                     3
#
# [22400 rows x 27 columns]

# %% [markdown]
# ## Data Partition
